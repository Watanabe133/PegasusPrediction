# %% [markdown]
# # モジュールインポート

# %%
import pandas as pd
import glob
import os
import time
import re
import datetime
from tqdm.notebook import tqdm
import dataclasses
from urllib.request import urlopen
from bs4 import BeautifulSoup
from selenium import webdriver
from abc import ABCMeta, abstractmethod
from types import MappingProxyType
from sklearn.preprocessing import LabelEncoder
import optuna.integration.lightgbm as lgb_o
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
from selenium.webdriver.common.by import By

# %%
@dataclasses.dataclass(frozen=True)
class UrlPaths:
    DOMAIN: str = 'https://db.netkeiba.com/'
    # レース結果表、レース情報表、払い戻し表が含まれるページ
    RACE_URL: str = DOMAIN + 'race/'
    # 馬の過去成績表のページ
    HORSE_URL: str = DOMAIN + 'horse/'
    # 血統表のページ
    PED_URL: str = HORSE_URL + 'ped/'
    
    TOP: str = 'https://race.netkeiba.com/top/'
    # 開催日程ページ
    CALENDAR_URL: str = TOP + 'calendar.html'
    # レース一覧ページ
    RACE_LIST_URL: str = TOP + 'race_list.html'
    
    # 出馬表ページ
    SHUTUBA_TABLE: str = 'https://race.netkeiba.com/race/shutuba.html'

# %%
@dataclasses.dataclass(frozen=True)
class LocalPaths:
   
    BASE_PATH: str = os.path.abspath('./')

    DATA_PATH: str = os.path.join(os.path.abspath('./'),'data')
  
    HTML_PATH: str = os.path.join(DATA_PATH, 'html')
    HTML_RACE_PATH: str = os.path.join(HTML_PATH, 'race')
    HTML_HORSE_PATH: str = os.path.join(HTML_PATH, 'horse')
    HTML_PED_PATH: str = os.path.join(HTML_PATH, 'ped')
    
    RAW_PATH: str = os.path.join(DATA_PATH, 'raw')
    RAW_RESULTS_PATH: str = os.path.join(RAW_PATH, 'results')
    RAW_RACE_INFO_PATH: str = os.path.join(RAW_PATH, 'race_info')
    RAW_RETURN_PATH: str = os.path.join(RAW_PATH, 'return_tables')
    RAW_HORSE_RESULTS_PATH: str = os.path.join(RAW_PATH, 'horse_results')
    RAW_PEDS_PATH: str = os.path.join(RAW_PATH, 'peds')

@dataclasses.dataclass(frozen=True)
class Master:
    PLACE_DICT: dict = MappingProxyType({
        '札幌':'01',
        '函館':'02',
        '福島':'03',
        '新潟':'04',
        '東京':'05',
        '中山':'06',
        '中京':'07',
        '京都':'08',
        '阪神':'09',
        '小倉':'10',
        '門別':'30',
        '旭川':'34',
        '盛岡':'35',
        '水沢':'36',
        '浦和':'42',
        '船橋':'43',
        '大井':'44',
        '川崎':'45',
        '金沢':'46',
        '笠松':'47',
        '名古屋':'48',
        '園田':'50',
        '姫路':'51',
        '福山':'53',
        '高知':'54',
        '佐賀':'55',
        '荒尾':'56',
        '札幌(地)':'58',
        '香港':'60',
        'フランス':'61',
        'オースト':'62',
        'イギリス':'63',
        'シャティ':'64',
        'アラブ首':'65',
        'メイダン':'66',
        'ドイツ':'67',
        'アイルラ':'68',
        'アメリカ':'69',
        'ロンシャ':'70',
        'イタリア':'71',
        'シンガポ':'72',
        'カナダ':'73',
        'シャンテ':'74',
        '韓国':'75',
        'フレミン':'76',
        'ニュージ':'77',
        'アスコッ':'78',
        'デルマー':'79',
        'サンタア':'80',
        'コーフィ':'81',
        'ベルモン':'82',
        'ドーヴィ':'83',
        'ランドウ':'84',
        'ヨーク':'85',
        'レパーズ':'86',
        'チャーチ':'87',
        'サンダウ':'88'
        })

    RACE_TYPE_DICT: dict = MappingProxyType({
        '芝': '芝',
        'ダ': 'ダート',
        '障': '障害',
        })
    
    WEATHER_LIST: tuple = ('晴', '曇', '小雨', '雨', '小雪', '雪')
    
    GROUND_STATE_LIST: tuple = ('良', '稍重', '重', '不良')
    
    SEX_LIST: tuple = ('牡', '牝', 'セ')
    
    AROUND_LIST: tuple = ('右', '左', '直線', '障害')

    RACE_CLASS_LIST: tuple = ('新馬', '未勝利', '1勝クラス', '2勝クラス', '3勝クラス', 'オープン', 'G3', 'G2', 'G1', '障害')

# %%
class FeatureEngineering:
    def __init__(self, data_merger: DataMerger):
        self.__data = data_merger.merged_data.copy()
        
    @property
    def featured_data(self):
        return self.__data
    
    def add_interval(self):
        self.__data['interval'] = (self.__data['date'] - self.__data['latest']).dt.days
        self.__data.drop('latest', axis=1, inplace=True)
        return self

    def add_agedays(self):
        self.__data['age_days'] = (self.__data['date'] - self.__data['birthday']).dt.days
        self.__data.drop('birthday', axis=1, inplace=True)
        return self
    
    def dumminize_weather(self):
        self.__data['weather'] = pd.Categorical(self.__data['weather'], Master.WEATHER_LIST)
        self.__data = pd.get_dummies(self.__data, columns=['weather'])
        return self
    
    def dumminize_race_type(self):
        self.__data['race_type'] = pd.Categorical(
            self.__data['race_type'], list(Master.RACE_TYPE_DICT.values())
            )
        self.__data = pd.get_dummies(self.__data, columns=['race_type'])
        return self
    
    def dumminize_ground_state(self):
        self.__data['ground_state'] = pd.Categorical(
            self.__data['ground_state'], Master.GROUND_STATE_LIST
            )
        self.__data = pd.get_dummies(self.__data, columns=['ground_state'])
        return self
    
    def dumminize_sex(self):
        self.__data['性'] = pd.Categorical(self.__data['性'], Master.SEX_LIST)
        self.__data = pd.get_dummies(self.__data, columns=['性'])
        return self
    
    def __label_encode(self, target_col: str):
        csv_path = os.path.join(LocalPaths.MASTER_DIR, target_col + '.csv')
        # ファイルが存在しない場合、空のDataFrameを作成
        if not os.path.isfile(csv_path):
            target_master = pd.DataFrame(columns=[target_col, 'encoded_id'])
        else:
            target_master = pd.read_csv(csv_path, dtype=object)

        target_master['encoded_id'] = target_master['encoded_id'].astype(int)

        new_target = self.__data[[target_col]][
            ~self.__data[target_col].isin(target_master[target_col])
            ].drop_duplicates(subset=[target_col])
        # 新しい情報を登録
        if len(target_master) > 0:
            new_target['encoded_id'] = [
                i+max(target_master['encoded_id']) for i in range(1, len(new_target)+1)
                ]
            # 整数に変換
            new_target['encoded_id'] = new_target['encoded_id'].astype(int)
        else: # まだ1行も登録されていない場合の処理
            new_target['encoded_id'] = [i for i in range(len(new_target))]
        # 元のマスタと繋げる
        new_target_master = pd.concat([target_master, new_target]).set_index(target_col)['encoded_id']
        # マスタファイルを更新
        new_target_master.to_csv(csv_path)
        # ラベルエンコーディング実行
        self.__data[target_col] = pd.Categorical(self.__data[target_col].map(new_target_master))
        return self
    
    def encode_horse_id(self):
        self.__label_encode('horse_id')
        return self
    
    def encode_jockey_id(self):
        self.__label_encode('jockey_id')
        return self
    
    def encode_trainer_id(self):
        self.__label_encode('trainer_id')
        return self

    def encode_owner_id(self):
        self.__label_encode('owner_id')
        return self

    def encode_breeder_id(self):
        self.__label_encode('breeder_id')
        return self

    def dumminize_kaisai(self):
        self.__data[HorseResultsCols.PLACE] = pd.Categorical(
            self.__data[HorseResultsCols.PLACE], list(Master.PLACE_DICT.values())
            )
        self.__data = pd.get_dummies(self.__data, columns=[HorseResultsCols.PLACE])
        return self

    def dumminize_around(self):
        self.__data['around'] = pd.Categorical(self.__data['around'], Master.AROUND_LIST)
        self.__data = pd.get_dummies(self.__data, columns=['around'])
        return self

    def dumminize_race_class(self):
        self.__data['race_class'] = pd.Categorical(self.__data['race_class'], Master.RACE_CLASS_LIST)
        self.__data = pd.get_dummies(self.__data, columns=['race_class'])
        return self

# %% [markdown]
# # 関数置き場
# ## 各セルをそのまま実行してもらえれば大丈夫です

# %%
def get_kaisai_date(from_: str, to_: str):
    date_range = pd.date_range(start=from_, end=to_, freq="M")
    kaisai_date_list = []
    for year, month in tqdm(zip(date_range.year, date_range.month), total=len(date_range)):
        query = ['year=' + str(year),'month=' + str(month),]
        url = UrlPaths.CALENDAR_URL + '?' + '&'.join(query)
        html = urlopen(url).read()
        time.sleep(1)
        soup = BeautifulSoup(html, "html.parser")
        a_list = soup.find('table', class_='Calendar_Table').find_all('a')
        for a in a_list:
            kaisai_date_list.append(re.findall('(?<=kaisai_date=)\d+', a['href'])[0])
    return kaisai_date_list

# %%
def get_race_id_list(kaisai_date_list: list):
    race_id_list = []
    driver = webdriver.Chrome()
    for kaisai_date in tqdm(kaisai_date_list):
        try:
            query = [
                'kaisai_date=' + str(kaisai_date)
            ]
            url = UrlPaths.RACE_LIST_URL + '?' + '&'.join(query)
            print('scraping: {}'.format(url))
            driver.get(url)
            try:
                time.sleep(1) #取得の猶予として1秒設けた
                a_list = driver.find_element(By.CLASS_NAME, 'RaceList_Box').find_elements(By.TAG_NAME, 'a')
            except: #それでも取得できなかった場合
                print('waiting more 10 seconds')
                time.sleep(10)
                a_list = driver.find_element(By.CLASS_NAME, 'RaceList_Box').find_elements(By.TAG_NAME, 'a')
            for a in a_list:
                race_id = re.findall('(?<=result.html\?race_id=)\d+', a.get_attribute('href'))
                if len(race_id) > 0:
                    race_id_list.append(race_id[0])
        except Exception as e:
            print(e)
            break
    driver.close()
    return race_id_list

# %%
def get_html_horse(horse_id_list: list, skip: bool = True):
    html_path_list = []
    for horse_id in tqdm(horse_id_list):
        url = 'https://db.netkeiba.com/horse/' + horse_id #horse_idのurl作成
        html = urlopen(url).read() #スクレイピング実行
        filename = 'data/html/horse/' + horse_id + '.bin'
        html_path_list.append(filename)
        if skip and os.path.isfile(filename): 
            print('horse_id {} skipped'.format(horse_id))
            continue
        with open(filename, 'wb') as f: #保存するファイルパスを指定
            f.write(html) #保存
        time.sleep(1) #サーバーが落ちないようにするため必須
    return html_path_list

def get_html_race(race_id_list: list, skip: bool = True):
    html_path_list = []
    for race_id in tqdm(race_id_list):
        url = 'https://db.netkeiba.com/race/' + race_id #race_idからurlを作る
        html = urlopen(url).read() #スクレイピング実行
        filename = 'data/html/race/' + race_id + '.bin'
        html_path_list.append(filename)
        if skip and os.path.isfile(filename): 
            print('race_id {} skipped'.format(race_id))
            continue
        with open(filename, 'wb') as f: #保存するファイルパスを指定
            f.write(html) #保存
        time.sleep(1) #サーバーが落ちないようにするため必須
    return html_path_list

def get_html_ped(horse_id_list: list, skip: bool = True):
    html_path_list = []
    for horse_id in tqdm(horse_id_list):
        url = 'https://db.netkeiba.com/horse/ped/' + horse_id #horse_idからurlを作る
        html = urlopen(url).read() #スクレイピング実行
        filename = 'data/html/ped/' + horse_id + '.bin'
        html_path_list.append(filename)
        if skip and os.path.isfile(filename): 
            print('horse_id {} skipped'.format(horse_id))
            continue
        with open(filename, 'wb') as f: #保存するファイルパスを指定
            f.write(html) #保存
        time.sleep(1) #サーバーが落ちないようにするため必須
    return html_path_list

# %%
def get_rawdata_results(html_path_list: list):
    race_results = {}
    for html_path in tqdm(html_path_list):
        with open(html_path, 'rb') as f:
            try:
                html = f.read() 
                df = pd.read_html(html)[0] #メインとなるレース結果表データを取得
                
                soup = BeautifulSoup(html, "html.parser") #htmlをsoupオブジェクトに変換

                horse_id_list = []
                horse_a_list = soup.find("table", attrs={"summary": "レース結果"}).find_all(
                    "a", attrs={"href": re.compile("^/horse")}
                )
                for a in horse_a_list:
                    horse_id = re.findall(r"\d+", a["href"])
                    horse_id_list.append(horse_id[0])
                jockey_id_list = []
                jockey_a_list = soup.find("table", attrs={"summary": "レース結果"}).find_all(
                    "a", attrs={"href": re.compile("^/jockey")}
                )
                for a in jockey_a_list:
                    jockey_id = re.findall(r"\d+", a["href"])
                    jockey_id_list.append(jockey_id[0])
                df["horse_id"] = horse_id_list
                df["jockey_id"] = jockey_id_list

                #インデックスをrace_idにする
                race_id = re.findall('(?<=race/)\d+', html_path)[0]
                df.index = [race_id] * len(df)

                race_results[race_id] = df
            except Exception as e:
                print('error at {}'.format(html_path))
                print(e)

    race_results_df = pd.concat([race_results[key] for key in race_results])

    return race_results_df

def get_rawdata_info(html_path_list: list):
    race_infos = {}
    for html_path in tqdm(html_path_list):
        with open(html_path, 'rb') as f:
            try:
                html = f.read() #保存してあるバイナリファイルを読み込む
                
                soup = BeautifulSoup(html, "html.parser") #htmlをsoupオブジェクトに変換

                texts = (
                    soup.find("div", attrs={"class": "data_intro"}).find_all("p")[0].text
                    + soup.find("div", attrs={"class": "data_intro"}).find_all("p")[1].text
                )
                info = re.findall(r'\w+', texts)
                df = pd.DataFrame()
                for text in info:
                    if text in ["芝", "ダート"]:
                        df["race_type"] = [text]
                    if "障" in text:
                        df["race_type"] = ["障害"]
                    if "m" in text:
                        df["course_len"] = [int(re.findall(r"\d+", text)[-1])] 
                    if text in ["良", "稍重", "重", "不良"]:
                        df["ground_state"] = [text]
                    if text in ["曇", "晴", "雨", "小雨", "小雪", "雪"]:
                        df["weather"] = [text]
                    if "年" in text:
                        df["date"] = [text]
                
                #インデックスをrace_idにする
                race_id = re.findall('(?<=race/)\d+', html_path)[0]
                df.index = [race_id] * len(df)

                race_infos[race_id] = df
            except Exception as e:
                print('error at {}'.format(html_path))
                print(e)

    race_infos_df = pd.concat([race_infos[key] for key in race_infos])

    return race_infos_df

def get_rawdata_return(html_path_list: list):
    horse_results = {}
    for html_path in tqdm(html_path_list):
        with open(html_path, 'rb') as f:
            try: 
                html = f.read() #保存してあるバイナリファイルを読み込む
                
                html = html.replace(b'<br />', b'br')
                dfs = pd.read_html(html)

                df = pd.concat([dfs[1], dfs[2]])
                
                race_id = re.findall('(?<=race/)\d+', html_path)[0]
                df.index = [race_id] * len(df)
                horse_results[race_id] = df
            except Exception as e:
                print('error at {}'.format(html_path))
                print(e)

    horse_results_df = pd.concat([horse_results[key] for key in horse_results])
    return horse_results_df

def get_rawdata_horse_results(html_path_list: list):
    horse_results = {}
    for html_path in tqdm(html_path_list):
        with open(html_path, 'rb') as f:
            html = f.read() #保存してあるバイナリファイルを読み込む
            
            df = pd.read_html(html)[3]
            if df.columns[0]=='受賞歴':
                df = pd.read_html(html)[4]
                
            horse_id = re.findall('(?<=horse/)\d+', html_path)[0]
            
            df.index = [horse_id] * len(df)
            horse_results[horse_id] = df
            
    horse_results_df = pd.concat([horse_results[key] for key in horse_results])
    return horse_results_df

def get_rawdata_peds(html_path_list: list):
    peds = {}
    for html_path in tqdm(html_path_list):
        with open(html_path, 'rb') as f:
            html = f.read() #保存してあるバイナリファイルを読み込む
            
            df = pd.read_html(html)[0]

            generations = {}
            horse_id = re.findall('(?<=ped/)\d+', html_path)[0]
            for i in reversed(range(5)):
                generations[i] = df[i]
                df.drop([i], axis=1, inplace=True)
                df = df.drop_duplicates()
            ped = pd.concat([generations[i] for i in range(5)]).rename(horse_id)
            peds[horse_id] = ped.reset_index(drop=True)

    peds_df = pd.concat([peds[key] for key in peds], axis=1).T.add_prefix('peds_')
    return peds_df

# %% [markdown]
# # A.データ取得

# %% [markdown]
# ## レースID取得

# %% [markdown]
# ## ※ここから自分で書き換える箇所あり
# #### （書き換え方）from_とto_の所で取得したい日時の範囲を指定する

# %%
#開催日取得
kaisai_date_2023 = get_kaisai_date(from_="2021-01-01", to_="2022-01-01")
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %% [markdown]
# #### （書き換え方）(kaisai_date_年数)として年数の部分を書き換える

# %%
# 開催日からレースIDを取得する
race_id_list = get_race_id_list(kaisai_date_2023)
# Out:
#   0%|          | 0/106 [00:00<?, ?it/s]
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210105
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210109
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210110
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210111
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210116
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210117
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210123
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210124
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210130
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210131
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210206
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210207
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210213
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210214
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210220
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210221
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210227
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210228
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210306
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210307
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210313
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210314
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210320
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210321
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210327
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210328
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210403
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210404
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210410
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210411
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210417
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210418
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210424
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210425
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210501
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210502
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210508
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210509
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210515
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210516
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210522
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210523
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210529
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210530
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210605
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210606
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210612
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210613
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210619
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210620
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210626
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210627
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210703
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210704
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210710
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210711
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210717
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210718
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210724
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210725
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210731
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210801
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210807
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210808
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210814
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210815
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210821
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210822
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210828
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210829
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210904
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210905
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210911
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210912
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210918
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210919
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210920
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210925
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20210926
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211002
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211003
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211009
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211010
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211016
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211017
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211023
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211024
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211030
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211031
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211106
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211107
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211113
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211114
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211120
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211121
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211127
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211128
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211204
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211205
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211211
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211212
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211218
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211219
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211225
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211226
# scraping: https://race.netkeiba.com/top/race_list.html?kaisai_date=20211228

# %% [markdown]
# ## レースデータ取得

# %%
#https://db.netkeiba.com/race/のhtml(バイナリファイル)をスクレイピングして保存
html_files_race = get_html_race(race_id_list)
html_files_race[:5]
# Out:
#   0%|          | 0/3456 [00:00<?, ?it/s]
# ['data/html/race/202106010101.bin',
#  'data/html/race/202106010102.bin',
#  'data/html/race/202106010103.bin',
#  'data/html/race/202106010104.bin',
#  'data/html/race/202106010105.bin']

# %%
results = get_rawdata_results(html_files_race) #レース結果表の作成
race_info = get_rawdata_info(html_files_race) #レース情報表の作成
return_table = get_rawdata_return(html_files_race) #払戻表の作成
# Out:
#   0%|          | 0/3456 [00:00<?, ?it/s]
# error at data/html/race/202110010405.bin
# 'NoneType' object has no attribute 'find_all'
# error at data/html/race/202104010403.bin
# 'NoneType' object has no attribute 'find_all'
# error at data/html/race/202105030103.bin
# 'NoneType' object has no attribute 'find_all'
# error at data/html/race/202105030603.bin
# 'NoneType' object has no attribute 'find_all'
# error at data/html/race/202104040305.bin
# 'NoneType' object has no attribute 'find_all'
# error at data/html/race/202104040502.bin
# 'NoneType' object has no attribute 'find_all'
# error at data/html/race/202104050202.bin
# 'NoneType' object has no attribute 'find_all'
#   0%|          | 0/3456 [00:00<?, ?it/s]
#   0%|          | 0/3456 [00:00<?, ?it/s]

# %% [markdown]
# #### （書き換え方）_年数の部分を書き換えると後で使いやすくなる

# %%
#保存（後で分かりやすいように年数を書き換える）
results.to_pickle('data/raw/results/results_2023.pickle')
race_info.to_pickle('data/raw/race_info/race_info_2023.pickle')
return_table.to_pickle('data/raw/return_tables/return_tables_2023.pickle')

# %% [markdown]
# ## 馬データ取得

# %%
horse_id_list = results['horse_id'].unique()
html_files_horse = get_html_horse(horse_id_list) #htmlをスクレイピング
# Out:
#   0%|          | 0/11561 [00:00<?, ?it/s]
# horse_id 2018106541 skipped
# horse_id 2018103805 skipped
# horse_id 2018101171 skipped
# horse_id 2018103832 skipped
# horse_id 2018102256 skipped
# horse_id 2018102289 skipped
# horse_id 2018104708 skipped
# horse_id 2018110132 skipped
# horse_id 2018102097 skipped
# horse_id 2018102382 skipped
# horse_id 2018100439 skipped
# horse_id 2018103330 skipped
# horse_id 2018104096 skipped
# horse_id 2018102938 skipped
# horse_id 2018104611 skipped
# horse_id 2018106428 skipped
# horse_id 2017104921 skipped
# horse_id 2017100035 skipped
# horse_id 2017101057 skipped
# horse_id 2017101910 skipped
# horse_id 2017103142 skipped
# horse_id 2017102848 skipped
# horse_id 2014106348 skipped
# horse_id 2017104947 skipped
# horse_id 2017102518 skipped
# horse_id 2018101071 skipped
# horse_id 2018102158 skipped
# horse_id 2018101771 skipped
# horse_id 2018106273 skipped
# horse_id 2018104843 skipped
# horse_id 2018101566 skipped
# horse_id 2018105831 skipped
# horse_id 2018104893 skipped
# horse_id 2018105269 skipped
# horse_id 2018100681 skipped
# horse_id 2018105162 skipped
# horse_id 2018106795 skipped
# horse_id 2018104698 skipped
# horse_id 2018105050 skipped
# horse_id 2018104911 skipped
# horse_id 2018110086 skipped
# horse_id 2017103942 skipped
# horse_id 2017102175 skipped
# horse_id 2014105509 skipped
# horse_id 2017101323 skipped
# horse_id 2016100757 skipped
# horse_id 2017102892 skipped
# horse_id 2015105399 skipped
# horse_id 2016105007 skipped
# horse_id 2014109151 skipped
# horse_id 2017110122 skipped
# horse_id 2017103482 skipped
# horse_id 2016105815 skipped
# horse_id 2016100467 skipped
# horse_id 2016102081 skipped
# horse_id 2015101034 skipped
# horse_id 2017104766 skipped
# horse_id 2014101340 skipped
# horse_id 2015100659 skipped
# horse_id 2014102153 skipped
# horse_id 2014105599 skipped
# horse_id 2014103584 skipped
# horse_id 2015100548 skipped
# horse_id 2018105349 skipped
# horse_id 2018105308 skipped
# horse_id 2018102961 skipped
# horse_id 2018104996 skipped
# horse_id 2018103018 skipped
# horse_id 2018104982 skipped
# horse_id 2018101001 skipped
# horse_id 2018104460 skipped
# horse_id 2018110118 skipped
# horse_id 2016104877 skipped
# horse_id 2017105508 skipped
# horse_id 2014100208 skipped
# horse_id 2016105802 skipped
# horse_id 2015100969 skipped
# horse_id 2016104451 skipped
# horse_id 2013105646 skipped
# horse_id 2015103627 skipped
# horse_id 2014104449 skipped
# horse_id 2016100272 skipped
# horse_id 2016102929 skipped
# horse_id 2017102170 skipped
# horse_id 2017110026 skipped
# horse_id 2016103323 skipped
# horse_id 2017105589 skipped
# horse_id 2014104031 skipped
# horse_id 2016104919 skipped
# horse_id 2014102449 skipped
# horse_id 2017102037 skipped
# horse_id 2018106211 skipped
# horse_id 2018106492 skipped
# horse_id 2018101178 skipped
# horse_id 2018106326 skipped
# horse_id 2018110126 skipped
# horse_id 2018105151 skipped
# horse_id 2018102451 skipped
# horse_id 2018104723 skipped
# horse_id 2018102195 skipped
# horse_id 2018104156 skipped
# horse_id 2018100424 skipped
# horse_id 2018105256 skipped
# horse_id 2018105935 skipped
# horse_id 2018105731 skipped
# horse_id 2018104053 skipped
# horse_id 2018103608 skipped
# horse_id 2017101534 skipped
# horse_id 2017101239 skipped
# horse_id 2016104677 skipped
# horse_id 2017100846 skipped
# horse_id 2017106722 skipped
# horse_id 2017103378 skipped
# horse_id 2016101534 skipped
# horse_id 2017104307 skipped
# horse_id 2018110137 skipped
# horse_id 2018104266 skipped
# horse_id 2018105529 skipped
# horse_id 2018104638 skipped
# horse_id 2018103983 skipped
# horse_id 2018106084 skipped
# horse_id 2018101660 skipped
# horse_id 2018104797 skipped
# horse_id 2018105295 skipped
# horse_id 2018101970 skipped
# horse_id 2018102665 skipped
# horse_id 2018105326 skipped
# horse_id 2018105213 skipped
# horse_id 2018104876 skipped
# horse_id 2018101796 skipped
# horse_id 2018101596 skipped
# horse_id 2017100751 skipped
# horse_id 2016104431 skipped
# horse_id 2017100924 skipped
# horse_id 2017101109 skipped
# horse_id 2014103514 skipped
# horse_id 2017101726 skipped
# horse_id 2013105645 skipped
# horse_id 2013103792 skipped
# horse_id 2015102013 skipped
# horse_id 2017102603 skipped
# horse_id 2014104048 skipped
# horse_id 2017101186 skipped
# horse_id 2017101755 skipped
# horse_id 2015101592 skipped
# horse_id 2017100436 skipped
# horse_id 2016105042 skipped
# horse_id 2016101841 skipped
# horse_id 2017105720 skipped
# horse_id 2014104516 skipped
# horse_id 2017103518 skipped
# horse_id 2016102177 skipped
# horse_id 2017105502 skipped
# horse_id 2017106115 skipped
# horse_id 2016104952 skipped
# horse_id 2015105411 skipped
# horse_id 2013100975 skipped
# horse_id 2016105502 skipped
# horse_id 2012102503 skipped
# horse_id 2015105008 skipped
# horse_id 2017105000 skipped
# horse_id 2016104452 skipped
# horse_id 2015104713 skipped
# horse_id 2014105081 skipped
# horse_id 2016100171 skipped
# horse_id 2016104414 skipped
# horse_id 2016103250 skipped
# horse_id 2015100635 skipped
# horse_id 2017105406 skipped
# horse_id 2016100596 skipped
# horse_id 2015104417 skipped
# horse_id 2014102036 skipped
# horse_id 2017110033 skipped
# horse_id 2015105214 skipped
# horse_id 2014105887 skipped
# horse_id 2015106423 skipped
# horse_id 2012101505 skipped
# horse_id 2016101163 skipped
# horse_id 2017105272 skipped
# horse_id 2016104232 skipped
# horse_id 2016105797 skipped
# horse_id 2015103357 skipped
# horse_id 2017106417 skipped
# horse_id 2017105661 skipped
# horse_id 2015105791 skipped
# horse_id 2016106007 skipped
# horse_id 2017103871 skipped
# horse_id 2015101342 skipped
# horse_id 2015104860 skipped
# horse_id 2017105437 skipped
# horse_id 2018104731 skipped
# horse_id 2018100173 skipped
# horse_id 2018100684 skipped
# horse_id 2018102394 skipped
# horse_id 2018103734 skipped
# horse_id 2018104562 skipped
# horse_id 2018100822 skipped
# horse_id 2018101474 skipped
# horse_id 2018105993 skipped
# horse_id 2018103186 skipped
# horse_id 2018104145 skipped
# horse_id 2018103735 skipped
# horse_id 2018104149 skipped
# horse_id 2018100577 skipped
# horse_id 2018106587 skipped
# horse_id 2018102686 skipped
# horse_id 2017104507 skipped
# horse_id 2017101700 skipped
# horse_id 2017104776 skipped
# horse_id 2017105481 skipped
# horse_id 2017105286 skipped
# horse_id 2014102558 skipped
# horse_id 2017101539 skipped
# horse_id 2017102766 skipped
# horse_id 2017105081 skipped
# horse_id 2017101761 skipped
# horse_id 2017104201 skipped
# horse_id 2017103334 skipped
# horse_id 2018100188 skipped
# horse_id 2018102142 skipped
# horse_id 2018101329 skipped
# horse_id 2018104462 skipped
# horse_id 2018104846 skipped
# horse_id 2018104711 skipped
# horse_id 2018102144 skipped
# horse_id 2018105299 skipped
# horse_id 2018104732 skipped
# horse_id 2018104196 skipped
# horse_id 2018102090 skipped
# horse_id 2018101630 skipped
# horse_id 2018105511 skipped
# horse_id 2018102172 skipped
# horse_id 2018101988 skipped
# horse_id 2017104994 skipped
# horse_id 2017100050 skipped
# horse_id 2016100059 skipped
# horse_id 2017100825 skipped
# horse_id 2016106262 skipped
# horse_id 2017100540 skipped
# horse_id 2012104463 skipped
# horse_id 2015104582 skipped
# horse_id 2011101814 skipped
# horse_id 2016104335 skipped
# horse_id 2012104392 skipped
# horse_id 2015101785 skipped
# horse_id 2014100814 skipped
# horse_id 2016103103 skipped
# horse_id 2016104491 skipped
# horse_id 2018103133 skipped
# horse_id 2018100219 skipped
# horse_id 2018104522 skipped
# horse_id 2018103711 skipped
# horse_id 2018102884 skipped
# horse_id 2018106144 skipped
# horse_id 2018104860 skipped
# horse_id 2018104959 skipped
# horse_id 2018100995 skipped
# horse_id 2016103518 skipped
# horse_id 2015101532 skipped
# horse_id 2015102038 skipped
# horse_id 2017102514 skipped
# horse_id 2016100939 skipped
# horse_id 2016102668 skipped
# horse_id 2016103448 skipped
# horse_id 2015110063 skipped
# horse_id 2015101281 skipped
# horse_id 2016104435 skipped
# horse_id 2017100404 skipped
# horse_id 2017100437 skipped
# horse_id 2017105193 skipped
# horse_id 2015103535 skipped
# horse_id 2015103616 skipped
# horse_id 2016102032 skipped
# horse_id 2015104714 skipped
# horse_id 2016104965 skipped
# horse_id 2017105452 skipped
# horse_id 2017104970 skipped
# horse_id 2014105802 skipped
# horse_id 2016103275 skipped
# horse_id 2016105013 skipped
# horse_id 2017105048 skipped
# horse_id 2016105493 skipped
# horse_id 2018105583 skipped
# horse_id 2018101746 skipped
# horse_id 2018104571 skipped
# horse_id 2018104738 skipped
# horse_id 2018105852 skipped
# horse_id 2018102066 skipped
# horse_id 2018104080 skipped
# horse_id 2018101989 skipped
# horse_id 2018104787 skipped
# horse_id 2018105331 skipped
# horse_id 2018103280 skipped
# horse_id 2018100818 skipped
# horse_id 2018102986 skipped
# horse_id 2018106571 skipped
# horse_id 2018105009 skipped
# horse_id 2018101012 skipped
# horse_id 2018105738 skipped
# horse_id 2018100858 skipped
# horse_id 2018101087 skipped
# horse_id 2018104965 skipped
# horse_id 2018104630 skipped
# horse_id 2018100994 skipped
# horse_id 2018109002 skipped
# horse_id 2018104829 skipped
# horse_id 2018103368 skipped
# horse_id 2018104406 skipped
# horse_id 2018100420 skipped
# horse_id 2018104713 skipped
# horse_id 2018105418 skipped
# horse_id 2018102899 skipped
# horse_id 2018104136 skipped
# horse_id 2018104578 skipped
# horse_id 2018103377 skipped
# horse_id 2018105273 skipped
# horse_id 2018105337 skipped
# horse_id 2018100493 skipped
# horse_id 2018104595 skipped
# horse_id 2018101573 skipped
# horse_id 2018102605 skipped
# horse_id 2018100410 skipped
# horse_id 2018110013 skipped
# horse_id 2018106146 skipped
# horse_id 2018104327 skipped
# horse_id 2018102060 skipped
# horse_id 2018106473 skipped
# horse_id 2018100897 skipped
# horse_id 2018102117 skipped
# horse_id 2018101946 skipped
# horse_id 2018100017 skipped
# horse_id 2018103229 skipped
# horse_id 2018100774 skipped
# horse_id 2018110131 skipped
# horse_id 2018110095 skipped
# horse_id 2018110017 skipped
# horse_id 2017105012 skipped
# horse_id 2016103146 skipped
# horse_id 2017104659 skipped
# horse_id 2017102196 skipped
# horse_id 2017101807 skipped
# horse_id 2017105937 skipped
# horse_id 2015100557 skipped
# horse_id 2017102645 skipped
# horse_id 2016104746 skipped
# horse_id 2017105443 skipped
# horse_id 2017100583 skipped
# horse_id 2017103722 skipped
# horse_id 2016103415 skipped
# horse_id 2017104873 skipped
# horse_id 2015106372 skipped
# horse_id 2016106126 skipped
# horse_id 2016100947 skipped
# horse_id 2016100206 skipped
# horse_id 2013104814 skipped
# horse_id 2017106085 skipped
# horse_id 2016105584 skipped
# horse_id 2017104106 skipped
# horse_id 2016103983 skipped
# horse_id 2014100583 skipped
# horse_id 2016103685 skipped
# horse_id 2016106228 skipped
# horse_id 2017104889 skipped
# horse_id 2015104364 skipped
# horse_id 2016106453 skipped
# horse_id 2016101149 skipped
# horse_id 2015100822 skipped
# horse_id 2016103730 skipped
# horse_id 2014104076 skipped
# horse_id 2015103875 skipped
# horse_id 2016102044 skipped
# horse_id 2017104129 skipped
# horse_id 2017104193 skipped
# horse_id 2017106270 skipped
# horse_id 2016103501 skipped
# horse_id 2017110119 skipped
# horse_id 2017102984 skipped
# horse_id 2015103391 skipped
# horse_id 2016100621 skipped
# horse_id 2017105471 skipped
# horse_id 2018100675 skipped
# horse_id 2018102989 skipped
# horse_id 2018103483 skipped
# horse_id 2018102826 skipped
# horse_id 2018102757 skipped
# horse_id 2018103354 skipped
# horse_id 2018104565 skipped
# horse_id 2018105473 skipped
# horse_id 2018104665 skipped
# horse_id 2018101033 skipped
# horse_id 2018106129 skipped
# horse_id 2018102062 skipped
# horse_id 2018106797 skipped
# horse_id 2018101462 skipped
# horse_id 2018105476 skipped
# horse_id 2018102651 skipped
# horse_id 2018103256 skipped
# horse_id 2016100158 skipped
# horse_id 2015100493 skipped
# horse_id 2016102184 skipped
# horse_id 2018104662 skipped
# horse_id 2018103513 skipped
# horse_id 2018103446 skipped
# horse_id 2018105238 skipped
# horse_id 2018102196 skipped
# horse_id 2018103264 skipped
# horse_id 2018103730 skipped
# horse_id 2018104932 skipped
# horse_id 2018105118 skipped
# horse_id 2018105488 skipped
# horse_id 2018104727 skipped
# horse_id 2018100953 skipped
# horse_id 2016103082 skipped
# horse_id 2017101562 skipped
# horse_id 2015104514 skipped
# horse_id 2017110173 skipped
# horse_id 2017110086 skipped
# horse_id 2016101058 skipped
# horse_id 2017104258 skipped
# horse_id 2017106027 skipped
# horse_id 2017102872 skipped
# horse_id 2017102562 skipped
# horse_id 2015104412 skipped
# horse_id 2017104314 skipped
# horse_id 2017102533 skipped
# horse_id 2016102615 skipped
# horse_id 2017103825 skipped
# horse_id 2015100849 skipped
# horse_id 2017105706 skipped
# horse_id 2015104349 skipped
# horse_id 2017100725 skipped
# horse_id 2015100559 skipped
# horse_id 2016105480 skipped
# horse_id 2017106236 skipped
# horse_id 2018102216 skipped
# horse_id 2018105992 skipped
# horse_id 2018106605 skipped
# horse_id 2018100073 skipped
# horse_id 2018106602 skipped
# horse_id 2018103926 skipped
# horse_id 2018102155 skipped
# horse_id 2018103205 skipped
# horse_id 2018100049 skipped
# horse_id 2016106606 skipped
# horse_id 2017101429 skipped
# horse_id 2017102838 skipped
# horse_id 2015101707 skipped
# horse_id 2016104480 skipped
# horse_id 2015101602 skipped
# horse_id 2016105211 skipped
# horse_id 2016101865 skipped
# horse_id 2014101029 skipped
# horse_id 2016105136 skipped
# horse_id 2016100794 skipped
# horse_id 2016105630 skipped
# horse_id 2016104231 skipped
# horse_id 2015102979 skipped
# horse_id 2016105547 skipped
# horse_id 2015101960 skipped
# horse_id 2016102663 skipped
# horse_id 2017100097 skipped
# horse_id 2016105200 skipped
# horse_id 2016104963 skipped
# horse_id 2016101814 skipped
# horse_id 2016100151 skipped
# horse_id 2017106000 skipped
# horse_id 2013103646 skipped
# horse_id 2016102080 skipped
# horse_id 2017101183 skipped
# horse_id 2015104811 skipped
# horse_id 2015104612 skipped
# horse_id 2016103668 skipped
# horse_id 2012102070 skipped
# horse_id 2016102735 skipped
# horse_id 2017103291 skipped
# horse_id 2018103121 skipped
# horse_id 2018105340 skipped
# horse_id 2018100008 skipped
# horse_id 2018103574 skipped
# horse_id 2018101964 skipped
# horse_id 2018106502 skipped
# horse_id 2018103596 skipped
# horse_id 2018101891 skipped
# horse_id 2018100891 skipped
# horse_id 2018100126 skipped
# horse_id 2018103993 skipped
# horse_id 2018106162 skipped
# horse_id 2018104514 skipped
# horse_id 2018103101 skipped
# horse_id 2018106834 skipped
# horse_id 2018105144 skipped
# horse_id 2018106399 skipped
# horse_id 2018106244 skipped
# horse_id 2018101210 skipped
# horse_id 2018103093 skipped
# horse_id 2018103308 skipped
# horse_id 2018104675 skipped
# horse_id 2018109080 skipped
# horse_id 2018106031 skipped
# horse_id 2018105790 skipped
# horse_id 2018100659 skipped
# horse_id 2018102047 skipped
# horse_id 2018100570 skipped
# horse_id 2018103084 skipped
# horse_id 2018104976 skipped
# horse_id 2018103063 skipped
# horse_id 2018106835 skipped
# horse_id 2018103430 skipped
# horse_id 2018106451 skipped
# horse_id 2018104339 skipped
# horse_id 2018100478 skipped
# horse_id 2018105495 skipped
# horse_id 2017105082 skipped
# horse_id 2017106319 skipped
# horse_id 2017106255 skipped
# horse_id 2017105587 skipped
# horse_id 2016105216 skipped
# horse_id 2017109161 skipped
# horse_id 2017104104 skipped
# horse_id 2016100305 skipped
# horse_id 2016104835 skipped
# horse_id 2017104799 skipped
# horse_id 2016104858 skipped
# horse_id 2017104985 skipped
# horse_id 2017106153 skipped
# horse_id 2017106125 skipped
# horse_id 2017105092 skipped
# horse_id 2016100550 skipped
# horse_id 2016105681 skipped
# horse_id 2016104819 skipped
# horse_id 2016104658 skipped
# horse_id 2017105067 skipped
# horse_id 2016104368 skipped
# horse_id 2016101465 skipped
# horse_id 2016110089 skipped
# horse_id 2016104423 skipped
# horse_id 2014102019 skipped
# horse_id 2014105542 skipped
# horse_id 2014102972 skipped
# horse_id 2018104945 skipped
# horse_id 2018106532 skipped
# horse_id 2018105008 skipped
# horse_id 2018105237 skipped
# horse_id 2018100693 skipped
# horse_id 2018100927 skipped
# horse_id 2018103560 skipped
# horse_id 2018103615 skipped
# horse_id 2018105392 skipped
# horse_id 2018105610 skipped
# horse_id 2018102077 skipped
# horse_id 2018102910 skipped
# horse_id 2018102595 skipped
# horse_id 2017101535 skipped
# horse_id 2017105315 skipped
# horse_id 2016100418 skipped
# horse_id 2016102109 skipped
# horse_id 2017103868 skipped
# horse_id 2017105834 skipped
# horse_id 2017106374 skipped
# horse_id 2017109029 skipped
# horse_id 2016100930 skipped
# horse_id 2018102215 skipped
# horse_id 2018101817 skipped
# horse_id 2018102247 skipped
# horse_id 2018105984 skipped
# horse_id 2018100905 skipped
# horse_id 2018102799 skipped
# horse_id 2018103755 skipped
# horse_id 2018104207 skipped
# horse_id 2018102988 skipped
# horse_id 2018101245 skipped
# horse_id 2018102009 skipped
# horse_id 2018100821 skipped
# horse_id 2018106035 skipped
# horse_id 2018103470 skipped
# horse_id 2018104018 skipped
# horse_id 2018103489 skipped
# horse_id 2018101553 skipped
# horse_id 2018100752 skipped
# horse_id 2018106311 skipped
# horse_id 2018102845 skipped
# horse_id 2018103702 skipped
# horse_id 2018106902 skipped
# horse_id 2018103007 skipped
# horse_id 2018100601 skipped
# horse_id 2018105947 skipped
# horse_id 2018101646 skipped
# horse_id 2018103916 skipped
# horse_id 2018103534 skipped
# horse_id 2018110112 skipped
# horse_id 2018110010 skipped
# horse_id 2018102528 skipped
# horse_id 2017102141 skipped
# horse_id 2017104315 skipped
# horse_id 2017105287 skipped
# horse_id 2017103619 skipped
# horse_id 2017101531 skipped
# horse_id 2017101877 skipped
# horse_id 2015102743 skipped
# horse_id 2016103101 skipped
# horse_id 2017105978 skipped
# horse_id 2016104027 skipped
# horse_id 2016106181 skipped
# horse_id 2015103845 skipped
# horse_id 2016105718 skipped
# horse_id 2013105140 skipped
# horse_id 2017103299 skipped
# horse_id 2014101462 skipped
# horse_id 2014100050 skipped
# horse_id 2017103912 skipped
# horse_id 2017102612 skipped
# horse_id 2016101917 skipped
# horse_id 2016106547 skipped
# horse_id 2016104519 skipped
# horse_id 2017109028 skipped
# horse_id 2017103788 skipped
# horse_id 2014106286 skipped
# horse_id 2017105460 skipped
# horse_id 2017101419 skipped
# horse_id 2017104637 skipped
# horse_id 2017105438 skipped
# horse_id 2017105703 skipped
# horse_id 2017105408 skipped
# horse_id 2015101702 skipped
# horse_id 2014105947 skipped
# horse_id 2014103156 skipped
# horse_id 2016104397 skipped
# horse_id 2018105181 skipped
# horse_id 2018105824 skipped
# horse_id 2018105253 skipped
# horse_id 2018104750 skipped
# horse_id 2018106603 skipped
# horse_id 2018104696 skipped
# horse_id 2018104000 skipped
# horse_id 2018100190 skipped
# horse_id 2018104520 skipped
# horse_id 2018105830 skipped
# horse_id 2018102184 skipped
# horse_id 2018104208 skipped
# horse_id 2018105383 skipped
# horse_id 2018106582 skipped
# horse_id 2017105137 skipped
# horse_id 2016101075 skipped
# horse_id 2017101940 skipped
# horse_id 2017100160 skipped
# horse_id 2017104700 skipped
# horse_id 2016102229 skipped
# horse_id 2017101417 skipped
# horse_id 2017101525 skipped
# horse_id 2016100255 skipped
# horse_id 2017105063 skipped
# horse_id 2015105440 skipped
# horse_id 2018104694 skipped
# horse_id 2018104345 skipped
# horse_id 2018103198 skipped
# horse_id 2018104796 skipped
# horse_id 2018105106 skipped
# horse_id 2018103303 skipped
# horse_id 2018103087 skipped
# horse_id 2018106553 skipped
# horse_id 2018101834 skipped
# horse_id 2018110114 skipped
# horse_id 2018110076 skipped
# horse_id 2018105276 skipped
# horse_id 2018101127 skipped
# horse_id 2018104616 skipped
# horse_id 2018101175 skipped
# horse_id 2018105809 skipped
# horse_id 2018105908 skipped
# horse_id 2018104850 skipped
# horse_id 2018103565 skipped
# horse_id 2018102054 skipped
# horse_id 2018106552 skipped
# horse_id 2018103611 skipped
# horse_id 2018105357 skipped
# horse_id 2018103181 skipped
# horse_id 2018102831 skipped
# horse_id 2018110129 skipped
# horse_id 2018101455 skipped
# horse_id 2018106319 skipped
# horse_id 2018105701 skipped
# horse_id 2017103110 skipped
# horse_id 2016101167 skipped
# horse_id 2017101193 skipped
# horse_id 2017100956 skipped
# horse_id 2017105400 skipped
# horse_id 2016102188 skipped
# horse_id 2017104573 skipped
# horse_id 2017103952 skipped
# horse_id 2017105236 skipped
# horse_id 2017105301 skipped
# horse_id 2017100993 skipped
# horse_id 2016103787 skipped
# horse_id 2017106038 skipped
# horse_id 2017101725 skipped
# horse_id 2014104240 skipped
# horse_id 2017106413 skipped
# horse_id 2016105952 skipped
# horse_id 2017101731 skipped
# horse_id 2017103319 skipped
# horse_id 2016104424 skipped
# horse_id 2017105807 skipped
# horse_id 2016110126 skipped
# horse_id 2016100805 skipped
# horse_id 2017103874 skipped
# horse_id 2016100040 skipped
# horse_id 2015100637 skipped
# horse_id 2017110172 skipped
# horse_id 2017106334 skipped
# horse_id 2015104909 skipped
# horse_id 2015106174 skipped
# horse_id 2017103441 skipped
# horse_id 2016105066 skipped
# horse_id 2016104762 skipped
# horse_id 2016102056 skipped
# horse_id 2012104440 skipped
# horse_id 2016104564 skipped
# horse_id 2016100559 skipped
# horse_id 2017104964 skipped
# horse_id 2017103513 skipped
# horse_id 2016105926 skipped
# horse_id 2016102633 skipped
# horse_id 2017103504 skipped
# horse_id 2016103291 skipped
# horse_id 2014100618 skipped
# horse_id 2013106012 skipped
# horse_id 2016104787 skipped
# horse_id 2016102214 skipped
# horse_id 2017102385 skipped
# horse_id 2017106372 skipped
# horse_id 2017105231 skipped
# horse_id 2014105582 skipped
# horse_id 2016101717 skipped
# horse_id 2015104862 skipped
# horse_id 2017100593 skipped
# horse_id 2017104688 skipped
# horse_id 2017104725 skipped
# horse_id 2017105522 skipped
# horse_id 2017100169 skipped
# horse_id 2018100562 skipped
# horse_id 2018104592 skipped
# horse_id 2018101072 skipped
# horse_id 2018103540 skipped
# horse_id 2018101335 skipped
# horse_id 2018101712 skipped
# horse_id 2018105310 skipped
# horse_id 2018101662 skipped
# horse_id 2018106315 skipped
# horse_id 2018106183 skipped
# horse_id 2018101243 skipped
# horse_id 2018104029 skipped
# horse_id 2018102417 skipped
# horse_id 2018103538 skipped
# horse_id 2018101742 skipped
# horse_id 2018103319 skipped
# horse_id 2018105336 skipped
# horse_id 2018105207 skipped
# horse_id 2018105711 skipped
# horse_id 2018103204 skipped
# horse_id 2018106334 skipped
# horse_id 2018104563 skipped
# horse_id 2018105241 skipped
# horse_id 2018104250 skipped
# horse_id 2018100039 skipped
# horse_id 2017104941 skipped
# horse_id 2017100941 skipped
# horse_id 2017100167 skipped
# horse_id 2017105985 skipped
# horse_id 2016102174 skipped
# horse_id 2017102990 skipped
# horse_id 2016104330 skipped
# horse_id 2016105470 skipped
# horse_id 2016101324 skipped
# horse_id 2017106568 skipped
# horse_id 2017102164 skipped
# horse_id 2017102858 skipped
# horse_id 2017100682 skipped
# horse_id 2017101763 skipped
# horse_id 2015106356 skipped
# horse_id 2018100487 skipped
# horse_id 2018104914 skipped
# horse_id 2018105347 skipped
# horse_id 2018104745 skipped
# horse_id 2018109052 skipped
# horse_id 2018100226 skipped
# horse_id 2018102044 skipped
# horse_id 2018104298 skipped
# horse_id 2015101341 skipped
# horse_id 2016104749 skipped
# horse_id 2016105963 skipped
# horse_id 2016103414 skipped
# horse_id 2015100942 skipped
# horse_id 2017101765 skipped
# horse_id 2014102625 skipped
# horse_id 2017103814 skipped
# horse_id 2017106595 skipped
# horse_id 2015105850 skipped
# horse_id 2012103249 skipped
# horse_id 2016110013 skipped
# horse_id 2013101315 skipped
# horse_id 2016103990 skipped
# horse_id 2017105181 skipped
# horse_id 2017100511 skipped
# horse_id 2016104352 skipped
# horse_id 2017104691 skipped
# horse_id 2017105480 skipped
# horse_id 2017100251 skipped
# horse_id 2016100232 skipped
# horse_id 2016100587 skipped
# horse_id 2018101371 skipped
# horse_id 2018102328 skipped
# horse_id 2018104095 skipped
# horse_id 2018104129 skipped
# horse_id 2018102133 skipped
# horse_id 2018103149 skipped
# horse_id 2018101259 skipped
# horse_id 2018105569 skipped
# horse_id 2018105363 skipped
# horse_id 2018106466 skipped
# horse_id 2018102048 skipped
# horse_id 2018103077 skipped
# horse_id 2018100590 skipped
# horse_id 2018100763 skipped
# horse_id 2018104059 skipped
# horse_id 2018103861 skipped
# horse_id 2018101204 skipped
# horse_id 2018103147 skipped
# horse_id 2018103831 skipped
# horse_id 2018103058 skipped
# horse_id 2018101051 skipped
# horse_id 2018106469 skipped
# horse_id 2018102372 skipped
# horse_id 2018106581 skipped
# horse_id 2018104861 skipped
# horse_id 2018103927 skipped
# horse_id 2018105258 skipped
# horse_id 2018101616 skipped
# horse_id 2018104569 skipped
# horse_id 2018109101 skipped
# horse_id 2018106545 skipped
# horse_id 2018103620 skipped
# horse_id 2018105184 skipped
# horse_id 2018104966 skipped
# horse_id 2018104267 skipped
# horse_id 2018105401 skipped
# horse_id 2018105411 skipped
# horse_id 2018105505 skipped
# horse_id 2018104627 skipped
# horse_id 2018102178 skipped
# horse_id 2018104346 skipped
# horse_id 2018104658 skipped
# horse_id 2018104841 skipped
# horse_id 2015101903 skipped
# horse_id 2017100873 skipped
# horse_id 2015101771 skipped
# horse_id 2016105750 skipped
# horse_id 2016104066 skipped
# horse_id 2017104262 skipped
# horse_id 2017102992 skipped
# horse_id 2016101880 skipped
# horse_id 2016110070 skipped
# horse_id 2017110152 skipped
# horse_id 2016110131 skipped
# horse_id 2017102007 skipped
# horse_id 2017105109 skipped
# horse_id 2016104696 skipped
# horse_id 2017105297 skipped
# horse_id 2017102406 skipped
# horse_id 2018105355 skipped
# horse_id 2018101871 skipped
# horse_id 2018101486 skipped
# horse_id 2018104936 skipped
# horse_id 2018100740 skipped
# horse_id 2018104977 skipped
# horse_id 2018105595 skipped
# horse_id 2018102168 skipped
# horse_id 2018101452 skipped
# horse_id 2018104086 skipped
# horse_id 2017104804 skipped
# horse_id 2016105198 skipped
# horse_id 2017101792 skipped
# horse_id 2016105101 skipped
# horse_id 2016104611 skipped
# horse_id 2016102775 skipped
# horse_id 2016104470 skipped
# horse_id 2016104807 skipped
# horse_id 2017101415 skipped
# horse_id 2015100524 skipped
# horse_id 2017106018 skipped
# horse_id 2017106279 skipped
# horse_id 2015102824 skipped
# horse_id 2017101303 skipped
# horse_id 2017103473 skipped
# horse_id 2018100531 skipped
# horse_id 2018104310 skipped
# horse_id 2018103116 skipped
# horse_id 2018105647 skipped
# horse_id 2018105954 skipped
# horse_id 2018103870 skipped
# horse_id 2018100679 skipped
# horse_id 2018102238 skipped
# horse_id 2018105259 skipped
# horse_id 2018104340 skipped
# horse_id 2018104780 skipped
# horse_id 2018106305 skipped
# horse_id 2018105617 skipped
# horse_id 2018103314 skipped
# horse_id 2018100710 skipped
# horse_id 2018106443 skipped
# horse_id 2018104455 skipped
# horse_id 2018102544 skipped
# horse_id 2018101679 skipped
# horse_id 2017110146 skipped
# horse_id 2013103569 skipped
# horse_id 2014100645 skipped
# horse_id 2016100862 skipped
# horse_id 2016105770 skipped
# horse_id 2016104832 skipped
# horse_id 2016102034 skipped
# horse_id 2017104886 skipped
# horse_id 2018106354 skipped
# horse_id 2018103115 skipped
# horse_id 2018104097 skipped
# horse_id 2018100096 skipped
# horse_id 2018101299 skipped
# horse_id 2018105405 skipped
# horse_id 2018103302 skipped
# horse_id 2018105986 skipped
# horse_id 2018103445 skipped
# horse_id 2017110161 skipped
# horse_id 2017100601 skipped
# horse_id 2017110041 skipped
# horse_id 2016101114 skipped
# horse_id 2016102111 skipped
# horse_id 2017103885 skipped
# horse_id 2017103367 skipped
# horse_id 2017105100 skipped
# horse_id 2015102130 skipped
# horse_id 2017106172 skipped
# horse_id 2016101402 skipped
# horse_id 2016105530 skipped
# horse_id 2017106227 skipped
# horse_id 2017105343 skipped
# horse_id 2017103048 skipped
# horse_id 2016102113 skipped
# horse_id 2017102889 skipped
# horse_id 2016102733 skipped
# horse_id 2017106614 skipped
# horse_id 2017105663 skipped
# horse_id 2017104095 skipped
# horse_id 2017101924 skipped
# horse_id 2017104861 skipped
# horse_id 2017105132 skipped
# horse_id 2017101882 skipped
# horse_id 2017104067 skipped
# horse_id 2015104053 skipped
# horse_id 2017104055 skipped
# horse_id 2017105421 skipped
# horse_id 2017109097 skipped
# horse_id 2017103886 skipped
# horse_id 2017103895 skipped
# horse_id 2016100455 skipped
# horse_id 2016100970 skipped
# horse_id 2017102936 skipped
# horse_id 2016104351 skipped
# horse_id 2017106720 skipped
# horse_id 2015100887 skipped
# horse_id 2017101695 skipped
# horse_id 2017101797 skipped
# horse_id 2016104629 skipped
# horse_id 2016103022 skipped
# horse_id 2016103729 skipped
# horse_id 2017101334 skipped
# horse_id 2016104724 skipped
# horse_id 2017100163 skipped
# horse_id 2016104410 skipped
# horse_id 2018105333 skipped
# horse_id 2018101437 skipped
# horse_id 2018103973 skipped
# horse_id 2018103468 skipped
# horse_id 2018105819 skipped
# horse_id 2018104016 skipped
# horse_id 2018102433 skipped
# horse_id 2018105398 skipped
# horse_id 2018106000 skipped
# horse_id 2018102681 skipped
# horse_id 2018102181 skipped
# horse_id 2018106448 skipped
# horse_id 2018110091 skipped
# horse_id 2018103976 skipped
# horse_id 2018103341 skipped
# horse_id 2018103001 skipped
# horse_id 2018104939 skipped
# horse_id 2018104765 skipped
# horse_id 2018103929 skipped
# horse_id 2018105874 skipped
# horse_id 2018104908 skipped
# horse_id 2018104737 skipped
# horse_id 2018100373 skipped
# horse_id 2016101773 skipped
# horse_id 2017103437 skipped
# horse_id 2017104560 skipped
# horse_id 2017101571 skipped
# horse_id 2017103406 skipped
# horse_id 2015110093 skipped
# horse_id 2015101929 skipped
# horse_id 2017100614 skipped
# horse_id 2017110133 skipped
# horse_id 2017106360 skipped
# horse_id 2017105893 skipped
# horse_id 2017105636 skipped
# horse_id 2017106612 skipped
# horse_id 2017105144 skipped
# horse_id 2016101180 skipped
# horse_id 2017102675 skipped
# horse_id 2017102374 skipped
# horse_id 2017101967 skipped
# horse_id 2016103386 skipped
# horse_id 2017104266 skipped
# horse_id 2017101771 skipped
# horse_id 2017103025 skipped
# horse_id 2016106069 skipped
# horse_id 2017105135 skipped
# horse_id 2016102259 skipped
# horse_id 2016102450 skipped
# horse_id 2014101302 skipped
# horse_id 2016104222 skipped
# horse_id 2015101209 skipped
# horse_id 2017104862 skipped
# horse_id 2015105276 skipped
# horse_id 2017103295 skipped
# horse_id 2017105360 skipped
# horse_id 2016102073 skipped
# horse_id 2017103105 skipped
# horse_id 2015106125 skipped
# horse_id 2015102391 skipped
# horse_id 2014103571 skipped
# horse_id 2014100190 skipped
# horse_id 2015110073 skipped
# horse_id 2017103718 skipped
# horse_id 2014102973 skipped
# horse_id 2014103603 skipped
# horse_id 2015105225 skipped
# horse_id 2014103971 skipped
# horse_id 2018105277 skipped
# horse_id 2018100184 skipped
# horse_id 2018105161 skipped
# horse_id 2018105054 skipped
# horse_id 2018104261 skipped
# horse_id 2018102943 skipped
# horse_id 2018105404 skipped
# horse_id 2018106692 skipped
# horse_id 2018100719 skipped
# horse_id 2018110090 skipped
# horse_id 2017104253 skipped
# horse_id 2017106240 skipped
# horse_id 2016102670 skipped
# horse_id 2017104705 skipped
# horse_id 2017110103 skipped
# horse_id 2016105622 skipped
# horse_id 2015103675 skipped
# horse_id 2016102950 skipped
# horse_id 2018106697 skipped
# horse_id 2018100623 skipped
# horse_id 2018100174 skipped
# horse_id 2018104164 skipped
# horse_id 2018101677 skipped
# horse_id 2018102592 skipped
# horse_id 2018101215 skipped
# horse_id 2018105438 skipped
# horse_id 2018101337 skipped
# horse_id 2018103195 skipped
# horse_id 2018105785 skipped
# horse_id 2018101103 skipped
# horse_id 2018102602 skipped
# horse_id 2018104139 skipped
# horse_id 2018103386 skipped
# horse_id 2018102715 skipped
# horse_id 2018104256 skipped
# horse_id 2018104721 skipped
# horse_id 2018105261 skipped
# horse_id 2018110075 skipped
# horse_id 2018104648 skipped
# horse_id 2018105105 skipped
# horse_id 2018105071 skipped
# horse_id 2018105327 skipped
# horse_id 2018100394 skipped
# horse_id 2018101924 skipped
# horse_id 2018102006 skipped
# horse_id 2018102917 skipped
# horse_id 2018103206 skipped
# horse_id 2017105133 skipped
# horse_id 2017106650 skipped
# horse_id 2017106071 skipped
# horse_id 2017101791 skipped
# horse_id 2017102802 skipped
# horse_id 2016104841 skipped
# horse_id 2017104884 skipped
# horse_id 2017101363 skipped
# horse_id 2017105027 skipped
# horse_id 2017102491 skipped
# horse_id 2017109088 skipped
# horse_id 2016101391 skipped
# horse_id 2017104194 skipped
# horse_id 2016105715 skipped
# horse_id 2017109038 skipped
# horse_id 2017104137 skipped
# horse_id 2017104944 skipped
# horse_id 2014102088 skipped
# horse_id 2016102324 skipped
# horse_id 2018104475 skipped
# horse_id 2018104114 skipped
# horse_id 2018104162 skipped
# horse_id 2018104800 skipped
# horse_id 2018105562 skipped
# horse_id 2018105419 skipped
# horse_id 2018105474 skipped
# horse_id 2018100425 skipped
# horse_id 2017105789 skipped
# horse_id 2016103327 skipped
# horse_id 2014104092 skipped
# horse_id 2015104589 skipped
# horse_id 2017103898 skipped
# horse_id 2015100748 skipped
# horse_id 2015101377 skipped
# horse_id 2016110157 skipped
# horse_id 2015102735 skipped
# horse_id 2016104529 skipped
# horse_id 2017105214 skipped
# horse_id 2014105589 skipped
# horse_id 2015105076 skipped
# horse_id 2017105241 skipped
# horse_id 2017104685 skipped
# horse_id 2017100440 skipped
# horse_id 2017105574 skipped
# horse_id 2015105986 skipped
# horse_id 2016110115 skipped
# horse_id 2017105105 skipped
# horse_id 2014104329 skipped
# horse_id 2016104298 skipped
# horse_id 2016105457 skipped
# horse_id 2018103079 skipped
# horse_id 2018100764 skipped
# horse_id 2018102794 skipped
# horse_id 2018103050 skipped
# horse_id 2018101277 skipped
# horse_id 2018102827 skipped
# horse_id 2018101782 skipped
# horse_id 2018105530 skipped
# horse_id 2018103491 skipped
# horse_id 2018103529 skipped
# horse_id 2016100180 skipped
# horse_id 2017102178 skipped
# horse_id 2017101810 skipped
# horse_id 2017103418 skipped
# horse_id 2017106283 skipped
# horse_id 2017103167 skipped
# horse_id 2017103411 skipped
# horse_id 2016102156 skipped
# horse_id 2016103767 skipped
# horse_id 2016102194 skipped
# horse_id 2015104753 skipped
# horse_id 2018106723 skipped
# horse_id 2018102768 skipped
# horse_id 2018104477 skipped
# horse_id 2018105477 skipped
# horse_id 2018106881 skipped
# horse_id 2018105521 skipped
# horse_id 2018105035 skipped
# horse_id 2018102444 skipped
# horse_id 2018102574 skipped
# horse_id 2018105245 skipped
# horse_id 2018106508 skipped
# horse_id 2018101994 skipped
# horse_id 2018105365 skipped
# horse_id 2018105846 skipped
# horse_id 2018104591 skipped
# horse_id 2017103992 skipped
# horse_id 2017105493 skipped
# horse_id 2017104781 skipped
# horse_id 2016104400 skipped
# horse_id 2017103890 skipped
# horse_id 2017101448 skipped
# horse_id 2016101362 skipped
# horse_id 2015103213 skipped
# horse_id 2016105515 skipped
# horse_id 2016103459 skipped
# horse_id 2016100319 skipped
# horse_id 2017105192 skipped
# horse_id 2015106163 skipped
# horse_id 2017100367 skipped
# horse_id 2016100927 skipped
# horse_id 2015105401 skipped
# horse_id 2017102163 skipped
# horse_id 2017101756 skipped
# horse_id 2017104665 skipped
# horse_id 2017101919 skipped
# horse_id 2016102216 skipped
# horse_id 2017100464 skipped
# horse_id 2017101915 skipped
# horse_id 2017104917 skipped
# horse_id 2017101436 skipped
# horse_id 2017101451 skipped
# horse_id 2017100368 skipped
# horse_id 2017102952 skipped
# horse_id 2017104681 skipped
# horse_id 2017101523 skipped
# horse_id 2017104961 skipped
# horse_id 2017101800 skipped
# horse_id 2015106286 skipped
# horse_id 2017106699 skipped
# horse_id 2015100902 skipped
# horse_id 2014103266 skipped
# horse_id 2014103358 skipped
# horse_id 2016105537 skipped
# horse_id 2014101173 skipped
# horse_id 2017101831 skipped
# horse_id 2017101833 skipped
# horse_id 2017104093 skipped
# horse_id 2017105396 skipped
# horse_id 2016104883 skipped
# horse_id 2015104724 skipped
# horse_id 2017101367 skipped
# horse_id 2016110056 skipped
# horse_id 2016102102 skipped
# horse_id 2018104644 skipped
# horse_id 2018105230 skipped
# horse_id 2018101498 skipped
# horse_id 2018105604 skipped
# horse_id 2018104835 skipped
# horse_id 2018100074 skipped
# horse_id 2018101894 skipped
# horse_id 2018104819 skipped
# horse_id 2018105678 skipped
# horse_id 2018102338 skipped
# horse_id 2018104105 skipped
# horse_id 2018110035 skipped
# horse_id 2018103957 skipped
# horse_id 2018104935 skipped
# horse_id 2018101604 skipped
# horse_id 2018101728 skipped
# horse_id 2018105344 skipped
# horse_id 2018102698 skipped
# horse_id 2018102231 skipped
# horse_id 2018103160 skipped
# horse_id 2018100755 skipped
# horse_id 2018106097 skipped
# horse_id 2018110070 skipped
# horse_id 2018105317 skipped
# horse_id 2018106155 skipped
# horse_id 2018104775 skipped
# horse_id 2018103705 skipped
# horse_id 2018102120 skipped
# horse_id 2018103276 skipped
# horse_id 2018104365 skipped
# horse_id 2017110066 skipped
# horse_id 2017105122 skipped
# horse_id 2017105074 skipped
# horse_id 2016100758 skipped
# horse_id 2016100359 skipped
# horse_id 2016103338 skipped
# horse_id 2016104692 skipped
# horse_id 2017109090 skipped
# horse_id 2016104808 skipped
# horse_id 2015105852 skipped
# horse_id 2017101423 skipped
# horse_id 2017104141 skipped
# horse_id 2016103064 skipped
# horse_id 2016104634 skipped
# horse_id 2016100752 skipped
# horse_id 2016105051 skipped
# horse_id 2016100746 skipped
# horse_id 2017106303 skipped
# horse_id 2017104478 skipped
# horse_id 2017105910 skipped
# horse_id 2016105270 skipped
# horse_id 2017101746 skipped
# horse_id 2016100273 skipped
# horse_id 2014105709 skipped
# horse_id 2017104670 skipped
# horse_id 2015102558 skipped
# horse_id 2016103872 skipped
# horse_id 2017105621 skipped
# horse_id 2015105451 skipped
# horse_id 2018102649 skipped
# horse_id 2018102535 skipped
# horse_id 2018103603 skipped
# horse_id 2018103749 skipped
# horse_id 2018100886 skipped
# horse_id 2018103724 skipped
# horse_id 2018106459 skipped
# horse_id 2018103304 skipped
# horse_id 2018102902 skipped
# horse_id 2018106580 skipped
# horse_id 2018100924 skipped
# horse_id 2018104380 skipped
# horse_id 2018104944 skipped
# horse_id 2018105263 skipped
# horse_id 2018100389 skipped
# horse_id 2018102057 skipped
# horse_id 2018105215 skipped
# horse_id 2018101008 skipped
# horse_id 2017102191 skipped
# horse_id 2017100622 skipped
# horse_id 2016105215 skipped
# horse_id 2017102378 skipped
# horse_id 2017105500 skipped
# horse_id 2017100796 skipped
# horse_id 2018101617 skipped
# horse_id 2018105478 skipped
# horse_id 2018105251 skipped
# horse_id 2018105033 skipped
# horse_id 2018104883 skipped
# horse_id 2017104172 skipped
# horse_id 2015100509 skipped
# horse_id 2017103554 skipped
# horse_id 2015104950 skipped
# horse_id 2015103247 skipped
# horse_id 2016101344 skipped
# horse_id 2017110120 skipped
# horse_id 2012102486 skipped
# horse_id 2015100894 skipped
# horse_id 2012100683 skipped
# horse_id 2017101804 skipped
# horse_id 2015104047 skipped
# horse_id 2015103867 skipped
# horse_id 2018109105 skipped
# horse_id 2018105137 skipped
# horse_id 2018106397 skipped
# horse_id 2018100545 skipped
# horse_id 2018103402 skipped
# horse_id 2018105605 skipped
# horse_id 2018103796 skipped
# horse_id 2018104909 skipped
# horse_id 2018103902 skipped
# horse_id 2014103040 skipped
# horse_id 2013103687 skipped
# horse_id 2013103671 skipped
# horse_id 2014104991 skipped
# horse_id 2015110005 skipped
# horse_id 2013104030 skipped
# horse_id 2016100170 skipped
# horse_id 2018103411 skipped
# horse_id 2018105021 skipped
# horse_id 2018106345 skipped
# horse_id 2017102769 skipped
# horse_id 2017100218 skipped
# horse_id 2016105686 skipped
# horse_id 2017106369 skipped
# horse_id 2016102097 skipped
# horse_id 2017105005 skipped
# horse_id 2017102595 skipped
# horse_id 2017102946 skipped
# horse_id 2016105759 skipped
# horse_id 2017101369 skipped
# horse_id 2017100357 skipped
# horse_id 2016105226 skipped
# horse_id 2017105590 skipped
# horse_id 2017104904 skipped
# horse_id 2017100717 skipped
# horse_id 2017105616 skipped
# horse_id 2018104239 skipped
# horse_id 2018106601 skipped
# horse_id 2018100483 skipped
# horse_id 2018104878 skipped
# horse_id 2018106254 skipped
# horse_id 2018106058 skipped
# horse_id 2018103618 skipped
# horse_id 2018105223 skipped
# horse_id 2018104041 skipped
# horse_id 2018101774 skipped
# horse_id 2018106837 skipped
# horse_id 2018105042 skipped
# horse_id 2018101632 skipped
# horse_id 2018101730 skipped
# horse_id 2017106404 skipped
# horse_id 2016105662 skipped
# horse_id 2016101646 skipped
# horse_id 2017102543 skipped
# horse_id 2017100531 skipped
# horse_id 2016105186 skipped
# horse_id 2017104704 skipped
# horse_id 2017104092 skipped
# horse_id 2016102801 skipped
# horse_id 2017103293 skipped
# horse_id 2017104932 skipped
# horse_id 2016105171 skipped
# horse_id 2017105642 skipped
# horse_id 2017105634 skipped
# horse_id 2017101291 skipped
# horse_id 2018106077 skipped
# horse_id 2018100963 skipped
# horse_id 2018104308 skipped
# horse_id 2018101497 skipped
# horse_id 2018106044 skipped
# horse_id 2018104762 skipped
# horse_id 2018102202 skipped
# horse_id 2018102811 skipped
# horse_id 2018100297 skipped
# horse_id 2017100969 skipped
# horse_id 2015100547 skipped
# horse_id 2017101162 skipped
# horse_id 2016103569 skipped
# horse_id 2018104913 skipped
# horse_id 2018101605 skipped
# horse_id 2018105432 skipped
# horse_id 2018104833 skipped
# horse_id 2018100960 skipped
# horse_id 2018105367 skipped
# horse_id 2018104803 skipped
# horse_id 2018103040 skipped
# horse_id 2018106811 skipped
# horse_id 2017105225 skipped
# horse_id 2017105276 skipped
# horse_id 2015101835 skipped
# horse_id 2017104130 skipped
# horse_id 2015101626 skipped
# horse_id 2015104567 skipped
# horse_id 2016104845 skipped
# horse_id 2016104430 skipped
# horse_id 2017110156 skipped
# horse_id 2018103563 skipped
# horse_id 2018102131 skipped
# horse_id 2018100428 skipped
# horse_id 2018104837 skipped
# horse_id 2018103997 skipped
# horse_id 2018105370 skipped
# horse_id 2017110067 skipped
# horse_id 2017103617 skipped
# horse_id 2014104550 skipped
# horse_id 2017102011 skipped
# horse_id 2016105047 skipped
# horse_id 2016102362 skipped
# horse_id 2015100958 skipped
# horse_id 2017105525 skipped
# horse_id 2017105567 skipped
# horse_id 2016105239 skipped
# horse_id 2015104287 skipped
# horse_id 2017101431 skipped
# horse_id 2016103387 skipped
# horse_id 2016100527 skipped
# horse_id 2016102867 skipped
# horse_id 2015101467 skipped
# horse_id 2014100235 skipped
# horse_id 2016104650 skipped
# horse_id 2016100503 skipped
# horse_id 2014105853 skipped
# horse_id 2014105324 skipped
# horse_id 2018106368 skipped
# horse_id 2018101928 skipped
# horse_id 2018102091 skipped
# horse_id 2018105561 skipped
# horse_id 2018106010 skipped
# horse_id 2018101198 skipped
# horse_id 2018105102 skipped
# horse_id 2018105311 skipped
# horse_id 2018103103 skipped
# horse_id 2018106529 skipped
# horse_id 2018106510 skipped
# horse_id 2018103270 skipped
# horse_id 2018104576 skipped
# horse_id 2018103340 skipped
# horse_id 2018101189 skipped
# horse_id 2018105043 skipped
# horse_id 2018105109 skipped
# horse_id 2018102226 skipped
# horse_id 2018104165 skipped
# horse_id 2018103232 skipped
# horse_id 2018102963 skipped
# horse_id 2017110174 skipped
# horse_id 2017101560 skipped
# horse_id 2016104253 skipped
# horse_id 2017105293 skipped
# horse_id 2017103688 skipped
# horse_id 2017106203 skipped
# horse_id 2017105111 skipped
# horse_id 2017104963 skipped
# horse_id 2017104989 skipped
# horse_id 2016100634 skipped
# horse_id 2017104103 skipped
# horse_id 2016104193 skipped
# horse_id 2016104340 skipped
# horse_id 2015103374 skipped
# horse_id 2017104619 skipped
# horse_id 2014110107 skipped
# horse_id 2016101455 skipped
# horse_id 2014104259 skipped
# horse_id 2017100378 skipped
# horse_id 2015104571 skipped
# horse_id 2016104624 skipped
# horse_id 2016100349 skipped
# horse_id 2015106156 skipped
# horse_id 2014104052 skipped
# horse_id 2016100285 skipped
# horse_id 2017101707 skipped
# horse_id 2016104717 skipped
# horse_id 2017106141 skipped
# horse_id 2018104986 skipped
# horse_id 2018106193 skipped
# horse_id 2018103159 skipped
# horse_id 2018102186 skipped
# horse_id 2018105205 skipped
# horse_id 2018104985 skipped
# horse_id 2018104687 skipped
# horse_id 2017103827 skipped
# horse_id 2017102371 skipped
# horse_id 2016110118 skipped
# horse_id 2017101524 skipped
# horse_id 2017101400 skipped
# horse_id 2017103331 skipped
# horse_id 2016106138 skipped
# horse_id 2018104949 skipped
# horse_id 2018102176 skipped
# horse_id 2018103473 skipped
# horse_id 2018105131 skipped
# horse_id 2017106365 skipped
# horse_id 2017102894 skipped
# horse_id 2014100729 skipped
# horse_id 2015105481 skipped
# horse_id 2017101945 skipped
# horse_id 2016105014 skipped
# horse_id 2017100426 skipped
# horse_id 2017104238 skipped
# horse_id 2017105202 skipped
# horse_id 2017105536 skipped
# horse_id 2017105640 skipped
# horse_id 2017104470 skipped
# horse_id 2017106383 skipped
# horse_id 2017104945 skipped
# horse_id 2015101382 skipped
# horse_id 2017102506 skipped
# horse_id 2017104484 skipped
# horse_id 2017102809 skipped
# horse_id 2017103023 skipped
# horse_id 2017102935 skipped
# horse_id 2017101355 skipped
# horse_id 2016102336 skipped
# horse_id 2017106704 skipped
# horse_id 2016105929 skipped
# horse_id 2017100887 skipped
# horse_id 2017100988 skipped
# horse_id 2013102840 skipped
# horse_id 2015101339 skipped
# horse_id 2016101093 skipped
# horse_id 2016104219 skipped
# horse_id 2016105526 skipped
# horse_id 2016101207 skipped
# horse_id 2016104840 skipped
# horse_id 2016104728 skipped
# horse_id 2016100126 skipped
# horse_id 2016105210 skipped
# horse_id 2017101909 skipped
# horse_id 2015104367 skipped
# horse_id 2017101146 skipped
# horse_id 2018105460 skipped
# horse_id 2018110068 skipped
# horse_id 2018104872 skipped
# horse_id 2018105671 skipped
# horse_id 2018103530 skipped
# horse_id 2018102398 skipped
# horse_id 2018104148 skipped
# horse_id 2018110064 skipped
# horse_id 2018106467 skipped
# horse_id 2018103872 skipped
# horse_id 2018106613 skipped
# horse_id 2018105762 skipped
# horse_id 2018101704 skipped
# horse_id 2018105264 skipped
# horse_id 2018104788 skipped
# horse_id 2018104602 skipped
# horse_id 2018105575 skipped
# horse_id 2018105231 skipped
# horse_id 2018103120 skipped
# horse_id 2018104379 skipped
# horse_id 2018104789 skipped
# horse_id 2016104243 skipped
# horse_id 2017102819 skipped
# horse_id 2017104747 skipped
# horse_id 2017103785 skipped
# horse_id 2017104721 skipped
# horse_id 2017101719 skipped
# horse_id 2015104010 skipped
# horse_id 2015101257 skipped
# horse_id 2015100918 skipped
# horse_id 2017110088 skipped
# horse_id 2014100484 skipped
# horse_id 2016110161 skipped
# horse_id 2018104896 skipped
# horse_id 2018102287 skipped
# horse_id 2018104347 skipped
# horse_id 2017105376 skipped
# horse_id 2015105105 skipped
# horse_id 2015101654 skipped
# horse_id 2015104317 skipped
# horse_id 2015105033 skipped
# horse_id 2016104672 skipped
# horse_id 2015103452 skipped
# horse_id 2016105093 skipped
# horse_id 2015100744 skipped
# horse_id 2015104810 skipped
# horse_id 2017101201 skipped
# horse_id 2016104818 skipped
# horse_id 2017100469 skipped
# horse_id 2017105620 skipped
# horse_id 2017102597 skipped
# horse_id 2018100708 skipped
# horse_id 2018105198 skipped
# horse_id 2018104706 skipped
# horse_id 2018106573 skipped
# horse_id 2018100621 skipped
# horse_id 2018100700 skipped
# horse_id 2018105214 skipped
# horse_id 2018101296 skipped
# horse_id 2018110097 skipped
# horse_id 2018110122 skipped
# horse_id 2018103819 skipped
# horse_id 2018105860 skipped
# horse_id 2018105076 skipped
# horse_id 2018104688 skipped
# horse_id 2018106569 skipped
# horse_id 2018104188 skipped
# horse_id 2018106372 skipped
# horse_id 2018102724 skipped
# horse_id 2017110138 skipped
# horse_id 2017105383 skipped
# horse_id 2017101777 skipped
# horse_id 2017106611 skipped
# horse_id 2016104908 skipped
# horse_id 2018105500 skipped
# horse_id 2018104875 skipped
# horse_id 2018104532 skipped
# horse_id 2016102133 skipped
# horse_id 2017105248 skipped
# horse_id 2016100617 skipped
# horse_id 2015101447 skipped
# horse_id 2017103485 skipped
# horse_id 2017101819 skipped
# horse_id 2017100257 skipped
# horse_id 2016104911 skipped
# horse_id 2017100084 skipped
# horse_id 2018106659 skipped
# horse_id 2018110021 skipped
# horse_id 2018103094 skipped
# horse_id 2018104894 skipped
# horse_id 2018104092 skipped
# horse_id 2017101475 skipped
# horse_id 2017101883 skipped
# horse_id 2017104956 skipped
# horse_id 2016103252 skipped
# horse_id 2013104025 skipped
# horse_id 2018105289 skipped
# horse_id 2018103931 skipped
# horse_id 2018106887 skipped
# horse_id 2018110135 skipped
# horse_id 2017100997 skipped
# horse_id 2015101367 skipped
# horse_id 2017105951 skipped
# horse_id 2017100373 skipped
# horse_id 2015110032 skipped
# horse_id 2013101904 skipped
# horse_id 2016100421 skipped
# horse_id 2015105550 skipped
# horse_id 2015102127 skipped
# horse_id 2017104988 skipped
# horse_id 2015103983 skipped
# horse_id 2017102171 skipped
# horse_id 2017101121 skipped
# horse_id 2017105537 skipped
# horse_id 2016101956 skipped
# horse_id 2017105060 skipped
# horse_id 2014103798 skipped
# horse_id 2018105283 skipped
# horse_id 2018100551 skipped
# horse_id 2018105621 skipped
# horse_id 2018104849 skipped
# horse_id 2018105036 skipped
# horse_id 2018105608 skipped
# horse_id 2018106606 skipped
# horse_id 2016104760 skipped
# horse_id 2016104166 skipped
# horse_id 2017103512 skipped
# horse_id 2017103607 skipped
# horse_id 2018109026 skipped
# horse_id 2018105049 skipped
# horse_id 2018104864 skipped
# horse_id 2018105249 skipped
# horse_id 2018103543 skipped
# horse_id 2018105345 skipped
# horse_id 2018104954 skipped
# horse_id 2018105066 skipped
# horse_id 2018101941 skipped
# horse_id 2018101615 skipped
# horse_id 2018100108 skipped
# horse_id 2018104778 skipped
# horse_id 2017104818 skipped
# horse_id 2017100447 skipped
# horse_id 2017110074 skipped
# horse_id 2016102641 skipped
# horse_id 2017104706 skipped
# horse_id 2016106527 skipped
# horse_id 2018105167 skipped
# horse_id 2018104756 skipped
# horse_id 2018106543 skipped
# horse_id 2018102608 skipped
# horse_id 2017105607 skipped
# horse_id 2016106292 skipped
# horse_id 2017101823 skipped
# horse_id 2016104926 skipped
# horse_id 2016102038 skipped
# horse_id 2016102493 skipped
# horse_id 2014105391 skipped
# horse_id 2016105188 skipped
# ...
# horse_id 2019104366 skipped
# horse_id 2019110089 skipped
# horse_id 2019103346 skipped
# horse_id 2019106785 skipped
# horse_id 2019100964 skipped
# horse_id 2019102341 skipped
# horse_id 2019105604 skipped
# horse_id 2019100328 skipped
# horse_id 2019101068 skipped
# horse_id 2019100637 skipped
# horse_id 2019104613 skipped
# horse_id 2019101051 skipped
# horse_id 2019103932 skipped
# horse_id 2019104467 skipped
# horse_id 2019104606 skipped
# horse_id 2019101531 skipped
# horse_id 2019106127 skipped
# horse_id 2019104455 skipped
# horse_id 2017103823 skipped
# horse_id 2019101005 skipped
# horse_id 2019105376 skipped
# horse_id 2019110105 skipped
# horse_id 2019103672 skipped
# horse_id 2019110021 skipped
# horse_id 2019105568 skipped
# horse_id 2019102731 skipped
# horse_id 2019101660 skipped
# horse_id 2019100601 skipped
# horse_id 2019103679 skipped
# horse_id 2019100582 skipped
# horse_id 2019101640 skipped
# horse_id 2019100251 skipped
# horse_id 2018110088 skipped
# horse_id 2019110111 skipped
# horse_id 2019105159 skipped
# horse_id 2019104818 skipped
# horse_id 2019104981 skipped
# horse_id 2019103364 skipped
# horse_id 2019110005 skipped
# horse_id 2019104960 skipped
# horse_id 2019102644 skipped
# horse_id 2019102323 skipped
# horse_id 2019104115 skipped
# horse_id 2017103776 skipped
# horse_id 2019105219 skipped
# horse_id 2019109100 skipped
# horse_id 2019106342 skipped
# horse_id 2019104666 skipped
# horse_id 2019104430 skipped
# horse_id 2019102383 skipped
# horse_id 2019103151 skipped
# horse_id 2019100740 skipped
# horse_id 2019104828 skipped
# horse_id 2019109076 skipped
# horse_id 2019100489 skipped
# horse_id 2019102692 skipped
# horse_id 2019100027 skipped
# horse_id 2019100305 skipped
# horse_id 2019101405 skipped
# horse_id 2019105431 skipped
# horse_id 2019104124 skipped
# horse_id 2019104159 skipped
# horse_id 2019107005 skipped
# horse_id 2019103018 skipped
# horse_id 2019105015 skipped
# horse_id 2019101893 skipped
# horse_id 2019103546 skipped
# horse_id 2019103720 skipped
# horse_id 2019101929 skipped
# horse_id 2019102328 skipped
# horse_id 2019102658 skipped
# horse_id 2019104210 skipped
# horse_id 2019103544 skipped
# horse_id 2018102997 skipped
# horse_id 2017101380 skipped
# horse_id 2018104884 skipped
# horse_id 2019105048 skipped
# horse_id 2019104527 skipped
# horse_id 2019105445 skipped
# horse_id 2019105043 skipped
# horse_id 2019104839 skipped
# horse_id 2019100638 skipped
# horse_id 2019105849 skipped
# horse_id 2019106381 skipped
# horse_id 2019105127 skipped
# horse_id 2019101535 skipped
# horse_id 2018101963 skipped
# horse_id 2018105117 skipped
# horse_id 2018109129 skipped
# horse_id 2016105024 skipped
# horse_id 2019102003 skipped
# horse_id 2019106738 skipped
# horse_id 2019106663 skipped
# horse_id 2019100387 skipped
# horse_id 2019104092 skipped
# horse_id 2019106734 skipped
# horse_id 2019105596 skipped
# horse_id 2019105992 skipped
# horse_id 2016104874 skipped
# horse_id 2019106526 skipped
# horse_id 2019104558 skipped
# horse_id 2019102436 skipped
# horse_id 2019103096 skipped
# horse_id 2019101465 skipped
# horse_id 2019101865 skipped
# horse_id 2019110106 skipped
# horse_id 2019104921 skipped
# horse_id 2019100284 skipped
# horse_id 2019110014 skipped
# horse_id 2019101851 skipped
# horse_id 2019104288 skipped
# horse_id 2019101273 skipped
# horse_id 2019104415 skipped
# horse_id 2019102326 skipped
# horse_id 2019105837 skipped
# horse_id 2019101998 skipped
# horse_id 2019101885 skipped
# horse_id 2019101792 skipped
# horse_id 2019102243 skipped
# horse_id 2019100855 skipped
# horse_id 2019100291 skipped
# horse_id 2019103395 skipped
# horse_id 2019103692 skipped
# horse_id 2019103332 skipped
# horse_id 2019109172 skipped
# horse_id 2019105546 skipped
# horse_id 2019105654 skipped
# horse_id 2019104821 skipped
# horse_id 2019100741 skipped
# horse_id 2019105029 skipped
# horse_id 2019106399 skipped
# horse_id 2019100612 skipped
# horse_id 2019102320 skipped
# horse_id 2019103780 skipped
# horse_id 2019104931 skipped
# horse_id 2019104808 skipped
# horse_id 2019103289 skipped
# horse_id 2019110101 skipped
# horse_id 2019105794 skipped
# horse_id 2019103562 skipped
# horse_id 2019101038 skipped
# horse_id 2019101649 skipped
# horse_id 2019102238 skipped
# horse_id 2019104816 skipped
# horse_id 2019105844 skipped
# horse_id 2019105540 skipped
# horse_id 2019101117 skipped
# horse_id 2019103081 skipped
# horse_id 2019105600 skipped
# horse_id 2019104543 skipped
# horse_id 2019100780 skipped
# horse_id 2019100502 skipped
# horse_id 2019100462 skipped
# horse_id 2015103057 skipped
# horse_id 2016101165 skipped
# horse_id 2017105212 skipped
# horse_id 2019105552 skipped
# horse_id 2019104329 skipped
# horse_id 2019101896 skipped
# horse_id 2019104354 skipped
# horse_id 2019105076 skipped
# horse_id 2019110084 skipped
# horse_id 2019110023 skipped
# horse_id 2019100461 skipped
# horse_id 2019103512 skipped
# horse_id 2018105183 skipped
# horse_id 2019106186 skipped
# horse_id 2019102374 skipped
# horse_id 2019106148 skipped
# horse_id 2019100685 skipped
# horse_id 2019102751 skipped
# horse_id 2019110086 skipped
# horse_id 2019103031 skipped
# horse_id 2019102404 skipped
# horse_id 2019103903 skipped
# horse_id 2019105050 skipped
# horse_id 2019104030 skipped
# horse_id 2015103306 skipped
# horse_id 2017106231 skipped
# horse_id 2019104896 skipped
# horse_id 2019105114 skipped
# horse_id 2019103768 skipped
# horse_id 2019110110 skipped
# horse_id 2019102930 skipped
# horse_id 2019101032 skipped
# horse_id 2019104104 skipped
# horse_id 2019107075 skipped
# horse_id 2019103200 skipped
# horse_id 2019105857 skipped
# horse_id 2019106714 skipped
# horse_id 2018106026 skipped
# horse_id 2019104421 skipped
# horse_id 2019105200 skipped
# horse_id 2019104681 skipped
# horse_id 2019105503 skipped
# horse_id 2019106453 skipped
# horse_id 2019106985 skipped
# horse_id 2019106121 skipped
# horse_id 2019103253 skipped
# horse_id 2019103016 skipped
# horse_id 2019100112 skipped
# horse_id 2019110037 skipped
# horse_id 2019100929 skipped
# horse_id 2019105725 skipped
# horse_id 2019105727 skipped
# horse_id 2019100614 skipped
# horse_id 2019104716 skipped
# horse_id 2019101359 skipped
# horse_id 2019110090 skipped
# horse_id 2019106248 skipped
# horse_id 2019102766 skipped
# horse_id 2019107032 skipped
# horse_id 2019105008 skipped
# horse_id 2019101014 skipped
# horse_id 2019103997 skipped
# horse_id 2018104022 skipped
# horse_id 2019105283 skipped
# horse_id 2019104476 skipped
# horse_id 2019105366 skipped
# horse_id 2019104126 skipped
# horse_id 2019102799 skipped
# horse_id 2019102627 skipped
# horse_id 2019106256 skipped
# horse_id 2019100665 skipped
# horse_id 2019106576 skipped
# horse_id 2019106389 skipped
# horse_id 2019102593 skipped
# horse_id 2019101487 skipped
# horse_id 2016103069 skipped
# horse_id 2017103332 skipped
# horse_id 2019105587 skipped
# horse_id 2016104990 skipped
# horse_id 2019100723 skipped
# horse_id 2019101780 skipped
# horse_id 2019103010 skipped
# horse_id 2019102159 skipped
# horse_id 2019103824 skipped
# horse_id 2019105967 skipped
# horse_id 2019105180 skipped
# horse_id 2019103318 skipped
# horse_id 2019100073 skipped
# horse_id 2019104393 skipped
# horse_id 2019105731 skipped
# horse_id 2019105289 skipped
# horse_id 2019106305 skipped
# horse_id 2019102393 skipped
# horse_id 2019101867 skipped
# horse_id 2019104756 skipped
# horse_id 2019105979 skipped
# horse_id 2019101605 skipped
# horse_id 2019101416 skipped
# horse_id 2019103826 skipped
# horse_id 2019101819 skipped
# horse_id 2019105808 skipped
# horse_id 2019100831 skipped
# horse_id 2019100766 skipped
# horse_id 2019106027 skipped
# horse_id 2016101404 skipped
# horse_id 2017101318 skipped
# horse_id 2017104712 skipped
# horse_id 2017102673 skipped
# horse_id 2018106352 skipped
# horse_id 2019105213 skipped
# horse_id 2019105139 skipped
# horse_id 2019105044 skipped
# horse_id 2019104538 skipped
# horse_id 2019105055 skipped
# horse_id 2019101434 skipped
# horse_id 2019106609 skipped
# horse_id 2019104883 skipped
# horse_id 2019100525 skipped
# horse_id 2019102171 skipped
# horse_id 2019107016 skipped
# horse_id 2019105404 skipped
# horse_id 2019102656 skipped
# horse_id 2019102223 skipped
# horse_id 2019100592 skipped
# horse_id 2019102737 skipped
# horse_id 2019105505 skipped
# horse_id 2019102596 skipped
# horse_id 2019110030 skipped
# horse_id 2019103788 skipped
# horse_id 2019102702 skipped
# horse_id 2019106471 skipped
# horse_id 2019102761 skipped
# horse_id 2019102739 skipped
# horse_id 2019103960 skipped
# horse_id 2019106554 skipped
# horse_id 2019101661 skipped
# horse_id 2019104029 skipped
# horse_id 2019105708 skipped
# horse_id 2019106036 skipped
# horse_id 2019109040 skipped
# horse_id 2019101939 skipped
# horse_id 2019104787 skipped
# horse_id 2019101217 skipped
# horse_id 2019103514 skipped
# horse_id 2019105258 skipped
# horse_id 2019103094 skipped
# horse_id 2019105336 skipped
# horse_id 2019101610 skipped
# horse_id 2019100292 skipped
# horse_id 2019110047 skipped
# horse_id 2019104638 skipped
# horse_id 2019106679 skipped
# horse_id 2019100310 skipped
# horse_id 2019103122 skipped
# horse_id 2019101583 skipped
# horse_id 2019101960 skipped
# horse_id 2019103577 skipped
# horse_id 2019103224 skipped
# horse_id 2019101508 skipped
# horse_id 2017105628 skipped
# horse_id 2016106395 skipped
# horse_id 2019105023 skipped
# horse_id 2019106521 skipped
# horse_id 2019103654 skipped
# horse_id 2019103407 skipped
# horse_id 2019100083 skipped
# horse_id 2019100360 skipped
# horse_id 2019102560 skipped
# horse_id 2019105092 skipped
# horse_id 2019103833 skipped
# horse_id 2019103285 skipped
# horse_id 2019105346 skipped
# horse_id 2019104912 skipped
# horse_id 2019106972 skipped
# horse_id 2019101938 skipped
# horse_id 2018102669 skipped
# horse_id 2019100749 skipped
# horse_id 2019106629 skipped
# horse_id 2019110059 skipped
# horse_id 2019100275 skipped
# horse_id 2019100712 skipped
# horse_id 2019102571 skipped
# horse_id 2019106765 skipped
# horse_id 2019105745 skipped
# horse_id 2019106566 skipped
# horse_id 2019101120 skipped
# horse_id 2019102726 skipped
# horse_id 2019101933 skipped
# horse_id 2019105172 skipped
# horse_id 2019100657 skipped
# horse_id 2019104530 skipped
# horse_id 2019105458 skipped
# horse_id 2019106419 skipped
# horse_id 2019100805 skipped
# horse_id 2019105248 skipped
# horse_id 2019105566 skipped
# horse_id 2019105314 skipped
# horse_id 2017106338 skipped
# horse_id 2017105594 skipped
# horse_id 2019105400 skipped
# horse_id 2019102874 skipped
# horse_id 2019105186 skipped
# horse_id 2019103302 skipped
# horse_id 2019105053 skipped
# horse_id 2019104208 skipped
# horse_id 2019101021 skipped
# horse_id 2019104089 skipped
# horse_id 2019105937 skipped
# horse_id 2019104525 skipped
# horse_id 2019109096 skipped
# horse_id 2019104109 skipped
# horse_id 2019102576 skipped
# horse_id 2019103580 skipped
# horse_id 2019110122 skipped
# horse_id 2019103794 skipped
# horse_id 2019101904 skipped
# horse_id 2019102898 skipped
# horse_id 2019106928 skipped
# horse_id 2019106637 skipped
# horse_id 2019102155 skipped
# horse_id 2019102303 skipped
# horse_id 2019104001 skipped
# horse_id 2019100039 skipped
# horse_id 2019105739 skipped
# horse_id 2019105223 skipped
# horse_id 2019102738 skipped
# horse_id 2019101795 skipped
# horse_id 2019102895 skipped
# horse_id 2019105188 skipped
# horse_id 2019106709 skipped
# horse_id 2019105060 skipped
# horse_id 2019100798 skipped
# horse_id 2019104817 skipped
# horse_id 2019103947 skipped
# horse_id 2019104784 skipped
# horse_id 2019104072 skipped
# horse_id 2019100754 skipped
# horse_id 2019101634 skipped
# horse_id 2019101294 skipped
# horse_id 2019103743 skipped
# horse_id 2019106247 skipped
# horse_id 2019106574 skipped
# horse_id 2019102911 skipped
# horse_id 2019104136 skipped
# horse_id 2019101595 skipped
# horse_id 2017103539 skipped
# horse_id 2017105533 skipped
# horse_id 2019100628 skipped
# horse_id 2019103662 skipped
# horse_id 2019105462 skipped
# horse_id 2019105647 skipped
# horse_id 2019105304 skipped
# horse_id 2019105395 skipped
# horse_id 2019102858 skipped
# horse_id 2017106511 skipped
# horse_id 2015101804 skipped
# horse_id 2017105116 skipped
# horse_id 2019105477 skipped
# horse_id 2019103014 skipped
# horse_id 2019105026 skipped
# horse_id 2019104959 skipped
# horse_id 2019101678 skipped
# horse_id 2019103834 skipped
# horse_id 2019102368 skipped
# horse_id 2019100522 skipped
# horse_id 2019102053 skipped
# horse_id 2019105264 skipped
# horse_id 2019101503 skipped
# horse_id 2019109053 skipped
# horse_id 2019104313 skipped
# horse_id 2019102395 skipped
# horse_id 2019101803 skipped
# horse_id 2019105370 skipped
# horse_id 2019103586 skipped
# horse_id 2019103211 skipped
# horse_id 2019103561 skipped
# horse_id 2019105354 skipped
# horse_id 2019104862 skipped
# horse_id 2019105598 skipped
# horse_id 2019106966 skipped
# horse_id 2019106546 skipped
# horse_id 2019103250 skipped
# horse_id 2016104078 skipped
# horse_id 2016104364 skipped
# horse_id 2017105588 skipped
# horse_id 2018105280 skipped
# horse_id 2019102350 skipped
# horse_id 2019106888 skipped
# horse_id 2019103506 skipped
# horse_id 2019106087 skipped
# horse_id 2019105388 skipped
# horse_id 2019104129 skipped
# horse_id 2019102554 skipped
# horse_id 2019105428 skipped
# horse_id 2019103418 skipped
# horse_id 2019106120 skipped
# horse_id 2019104630 skipped
# horse_id 2019103920 skipped
# horse_id 2019100586 skipped
# horse_id 2019103036 skipped
# horse_id 2019100874 skipped
# horse_id 2019101414 skipped
# horse_id 2019105308 skipped
# horse_id 2019105542 skipped
# horse_id 2019106856 skipped
# horse_id 2019105480 skipped
# horse_id 2019104477 skipped
# horse_id 2019102406 skipped
# horse_id 2019105059 skipped
# horse_id 2019102143 skipped
# horse_id 2019103309 skipped
# horse_id 2019106146 skipped
# horse_id 2019106688 skipped
# horse_id 2019102296 skipped
# horse_id 2019103147 skipped
# horse_id 2019106889 skipped
# horse_id 2019106702 skipped
# horse_id 2019109108 skipped
# horse_id 2019104519 skipped
# horse_id 2019105177 skipped
# horse_id 2019104024 skipped
# horse_id 2019102137 skipped
# horse_id 2019101606 skipped
# horse_id 2019100857 skipped
# horse_id 2019100450 skipped
# horse_id 2019105766 skipped
# horse_id 2019105759 skipped
# horse_id 2019106658 skipped
# horse_id 2019105324 skipped
# horse_id 2019102650 skipped
# horse_id 2019101396 skipped
# horse_id 2019104002 skipped
# horse_id 2019106919 skipped
# horse_id 2019104332 skipped
# horse_id 2019100008 skipped
# horse_id 2017106395 skipped
# horse_id 2016106456 skipped
# horse_id 2019110107 skipped
# horse_id 2016103294 skipped
# horse_id 2019101015 skipped
# horse_id 2019105013 skipped
# horse_id 2019103928 skipped
# horse_id 2019100635 skipped
# horse_id 2019101046 skipped
# horse_id 2019102948 skipped
# horse_id 2019106997 skipped
# horse_id 2019105502 skipped
# horse_id 2019105541 skipped
# horse_id 2019101187 skipped
# horse_id 2019105292 skipped
# horse_id 2019105522 skipped
# horse_id 2019104965 skipped
# horse_id 2019101976 skipped
# horse_id 2019104752 skipped
# horse_id 2019103591 skipped
# horse_id 2019100121 skipped
# horse_id 2019104628 skipped
# horse_id 2019104564 skipped
# horse_id 2019106184 skipped
# horse_id 2019102968 skipped
# horse_id 2019100523 skipped
# horse_id 2019101259 skipped
# horse_id 2019103139 skipped
# horse_id 2019101849 skipped
# horse_id 2019102505 skipped
# horse_id 2019106481 skipped
# horse_id 2019104003 skipped
# horse_id 2019105170 skipped
# horse_id 2019106651 skipped
# horse_id 2019103219 skipped
# horse_id 2019105700 skipped
# horse_id 2019106134 skipped
# horse_id 2019107054 skipped
# horse_id 2019101105 skipped
# horse_id 2019104144 skipped
# horse_id 2019102057 skipped
# horse_id 2019100696 skipped
# horse_id 2019102773 skipped
# horse_id 2019105941 skipped
# horse_id 2019104571 skipped
# horse_id 2019103009 skipped
# horse_id 2019101708 skipped
# horse_id 2019100787 skipped
# horse_id 2019100618 skipped
# horse_id 2019104567 skipped
# horse_id 2019105077 skipped
# horse_id 2019104619 skipped
# horse_id 2019100736 skipped
# horse_id 2019105807 skipped
# horse_id 2019105111 skipped
# horse_id 2019101671 skipped
# horse_id 2019104213 skipped
# horse_id 2019105300 skipped
# horse_id 2019106503 skipped
# horse_id 2019100759 skipped
# horse_id 2017101305 skipped
# horse_id 2018103048 skipped
# horse_id 2016106399 skipped
# horse_id 2016104376 skipped
# horse_id 2019101667 skipped
# horse_id 2019102065 skipped
# horse_id 2019102824 skipped
# horse_id 2019102817 skipped
# horse_id 2019105609 skipped
# horse_id 2019105087 skipped
# horse_id 2019104090 skipped
# horse_id 2019103392 skipped
# horse_id 2019104364 skipped
# horse_id 2019102572 skipped
# horse_id 2019103042 skipped
# horse_id 2019105976 skipped
# horse_id 2019104899 skipped
# horse_id 2019105146 skipped
# horse_id 2019103776 skipped
# horse_id 2019103029 skipped
# horse_id 2019100235 skipped
# horse_id 2019105485 skipped
# horse_id 2019104761 skipped

# %%
html_files_horse = []
for horse_id in tqdm(horse_id_list):
    file = glob.glob(os.path.join(LocalPaths.HTML_HORSE_PATH, horse_id+'*.bin'))[0]
    html_files_horse.append(file)
html_files_horse[:5]

# %% [markdown]
# #### （書き換え方）同様に_年数の部分を書き換えると後で扱いやすい

# %%
#後で分かりやすいように年数を書き換える
horse_results_2023 = get_rawdata_horse_results(html_files_horse) #馬の過去成績表の作成
horse_results_2023.to_pickle('data/raw/horse_results/horse_results_2023.pickle')

# %% [markdown]
# ## 血統表データ取得

# %%
html_files_peds = get_html_ped(horse_id_list) #htmlをスクレイピング

# %% [markdown]
# #### （書き換え方）同様に_年数の部分を書き換えると後で扱いやすい

# %%
#後で分かりやすいように年数を書き換える
peds_2023 = get_rawdata_peds(html_files_peds) #血統表の作成
peds_2023.to_pickle('data/raw/peds/peds_2023.pickle')

# %% [markdown]
# # B. 学習

# %% [markdown]
# ## 関数置き場

# %%
class AbstractBetPolicy(metaclass=ABCMeta):
    @abstractstaticmethod
    def judge(score_table, **params):
        pass

class AbstractScorePolicy(metaclass=ABCMeta):
    @staticmethod
    @abstractmethod
    def calc(model, X: pd.DataFrame) -> pd.DataFrame:
        raise NotImplementedError

class BasicScorePolicy(AbstractScorePolicy):
    """
    LightGBMの出力をそのままscoreとして計算。
    """
    @staticmethod
    def calc(model, X: pd.DataFrame) -> pd.DataFrame:
        return _calc(model, X)

class StdScorePolicy(AbstractScorePolicy):
    """
    レース内で標準化して、相対評価する。「レース内偏差値」のようなもの。
    """
    @staticmethod
    def calc(model, X: pd.DataFrame) -> pd.DataFrame:
        score_table = _calc(model, X)
        score_table[_SCORE] = _apply_scaler(score_table[_SCORE], _scaler_standard)
        return score_table

class MinMaxScorePolicy(AbstractScorePolicy):
    """
    レース内で標準化して、相対評価した後、全体を0~1にスケーリング。
    """
    @staticmethod
    def calc(model, X: pd.DataFrame) -> pd.DataFrame:
        score_table = _calc(model, X)
        score = _apply_scaler(score_table[_SCORE], _scaler_standard)
        min_ = score.min()
        score_table[_SCORE] = (score - min_) / (score.max() - min_)
        return score_table

# %%
class ResultsCols:
    RANK: str = '着順'
    WAKUBAN: str = '枠番'
    UMABAN: str = '馬番'
    HORSE_NAME: str = '馬名'
    SEX_AGE: str = '性齢'
    KINRYO: str = '斤量'
    JOCKEY: str = '騎手'
    TIME: str = 'タイム'
    RANK_DIFF: str = '着差'
    TANSHO_ODDS: str = '単勝'
    POPULARITY: str = '人気'
    WEIGHT_AND_DIFF: str = '馬体重'
    TRAINER: str = '調教師'

class DataSplitter:
    def __init__(self, featured_data, test_size, valid_size) -> None:
        self.__featured_data = featured_data
        self.train_valid_test_split(test_size, valid_size)

    def train_valid_test_split(self, test_size, valid_size):
        """
        訓練データとテストデータに分ける。さらに訓練データをoptuna用の訓練データと検証データに分ける。
        """
        self.__train_data, self.__test_data = self.__split_by_date(self.__featured_data, test_size=test_size)
        self.__train_data_optuna, self.__valid_data_optuna = self.__split_by_date(
            self.__train_data, test_size=valid_size
            )
        self.__lgb_train_optuna = lgb_o.Dataset(
            self.__train_data_optuna.drop(['rank', 'date', ResultsCols.TANSHO_ODDS], axis=1).values,
            self.__train_data_optuna['rank']
        )
        self.__lgb_valid_optuna = lgb_o.Dataset(
            self.__valid_data_optuna.drop(['rank', 'date', ResultsCols.TANSHO_ODDS], axis=1).values,
            self.__valid_data_optuna['rank']
        )
        # 説明変数と目的変数に分ける。開催はエラーなるので一度drop。
        self.__X_train = self.__train_data.drop(['rank', 'date', ResultsCols.TANSHO_ODDS], axis=1)
        self.__y_train = self.__train_data['rank']
        self.__X_test = self.__test_data.drop(['rank', 'date'], axis=1)
        self.__y_test = self.__test_data['rank']

    def __split_by_date(self, df, test_size):
        """
        時系列に沿って訓練データとテストデータに分ける関数。test_sizeは0~1。
        """
        sorted_id_list = df.sort_values("date").index.unique()
        train_id_list = sorted_id_list[: round(len(sorted_id_list) * (1 - test_size))]
        test_id_list = sorted_id_list[round(len(sorted_id_list) * (1 - test_size)) :]
        train = df.loc[train_id_list]
        test = df.loc[test_id_list]
        return train, test

    @property
    def featured_data(self):
        return self.__featured_data

    @property
    def train_data(self):
        return self.__train_data

    @property
    def test_data(self):
        return self.__test_data

    @property
    def train_data_optuna(self):
        return self.__train_data_optuna

    @property
    def valid_data_optuna(self):
        return self.__valid_data_optuna

    @property
    def lgb_train_optuna(self):
        return self.__lgb_train_optuna

    @property
    def lgb_valid_optuna(self):
        return self.__lgb_valid_optuna

    @property
    def X_train(self):
        return self.__X_train

    @property
    def y_train(self):
        return self.__y_train

    @property
    def X_test(self):
        return self.__X_test

    @property
    def y_test(self):
        return self.__y_test

class ModelWrapper:
    """
    モデルのハイパーパラメータチューニング・学習の処理が記述されたクラス。
    """
    def __init__(self):
        self.__lgb_model = lgb.LGBMClassifier(objective='binary')
        self.__feature_importance = None

    def tune_hyper_params(self, datasets: DataSplitter):
        """
        optunaによるチューニングを実行。
        """

        params = {'objective': 'binary'}

        # チューニング実行
        lgb_clf_o = lgb_o.train(
            params,
            datasets.lgb_train_optuna,
            valid_sets=(datasets.lgb_train_optuna, datasets.lgb_valid_optuna),
            verbose_eval=100,
            early_stopping_rounds=10,
            optuna_seed=100 # optunaのseed固定
            )

        # num_iterationsとearly_stopping_roundは今は使わないので削除
        tunedParams = {
            k: v for k, v in lgb_clf_o.params.items() if k not in ['num_iterations', 'early_stopping_round']
            }

        self.__lgb_model.set_params(**tunedParams)

    @property
    def params(self):
        return self.__lgb_model.get_params()

    def set_params(self, ex_params):
        """
        外部からハイパーパラメータを設定する場合。
        """
        self.__lgb_model.set_params(**ex_params)

    def train(self, datasets: DataSplitter):
        # 学習
        self.__lgb_model.fit(datasets.X_train.values, datasets.y_train.values)
        # AUCを計算して出力
        auc_train = roc_auc_score(
            datasets.y_train, self.__lgb_model.predict_proba(datasets.X_train)[:, 1]
            )
        auc_test = roc_auc_score(
            datasets.y_test,
            self.__lgb_model.predict_proba(datasets.X_test.drop([ResultsCols.TANSHO_ODDS], axis=1))[:, 1]
            )
        # 特徴量の重要度を記憶しておく
        self.__feature_importance = pd.DataFrame({
            "features": datasets.X_train.columns,
            "importance": self.__lgb_model.feature_importances_
            }).sort_values("importance", ascending=False)
        print('AUC: {:.3f}(train), {:.3f}(test)'.format(auc_train, auc_test))

    @property
    def feature_importance(self):
        return self.__feature_importance

    @property
    def lgb_model(self):
        return self.__lgb_model

    @lgb_model.setter
    def lgb_model(self, loaded):
        self.__lgb_model = loaded

# %%
from ._model_wrapper import ModelWrapper
from ._data_splitter import DataSplitter
from modules.policies import AbstractScorePolicy

class KeibaAI:
    """
    モデルの訓練や読み込み、実際に賭けるなどの処理を実行するクラス。
    """
    def __init__(self, datasets: DataSplitter):
        self.__datasets = datasets
        self.__model_wrapper = ModelWrapper()

    @property
    def datasets(self):
        return self.__datasets

    def train_with_tuning(self):
        self.__model_wrapper.tune_hyper_params(self.__datasets)
        self.__model_wrapper.train(self.__datasets)

    def get_params(self):
        """
        ハイパーパラメータを取得
        """
        return self.__model_wrapper.params

    def set_params(self, params):
        self.__model_wrapper.set_params(params)

    def calc_score(self, X: pd.DataFrame, score_policy: AbstractScorePolicy):
        return score_policy.calc(self.__model_wrapper.lgb_model, X)

    def decide_action(self, score_table: pd.DataFrame,
        bet_policy: AbstractBetPolicy, **params) -> dict:
        actions = bet_policy.judge(score_table, **params)

        return actions

# %%
class KeibaAIFactory:

    @staticmethod
    def create(featured_data, test_size = 0.3, valid_size = 0.3) -> KeibaAI:
        datasets = DataSplitter(featured_data, test_size, valid_size)
        return KeibaAI(datasets)

    @staticmethod
    def save(keibaAI: KeibaAI, version_name: str) -> None:
        yyyymmdd = datetime.date.today().strftime('%Y%m%d')
        # ディレクトリ作成
        os.makedirs(os.path.join('models', yyyymmdd), exist_ok=True)
        filepath_pickle = os.path.join('models', yyyymmdd, '{}.pickle'.format(version_name))
        with open(filepath_pickle, mode='wb') as f:
            dill.dump(keibaAI, f)
    
    @staticmethod
    def load(filepath: str) -> KeibaAI:
        with open(filepath, mode='rb') as f:
            return dill.load(f)

# %% [markdown]
# ### 以下で学習させる

# %%
keiba_ai = training.KeibaAIFactory.create(feature_enginnering.featured_data) #モデル作成
keiba_ai.train_with_tuning() #パラメータチューニングをして学習

# %%
#モデル保存。pickle形式でモデルとデータセットが保存される。
training.KeibaAIFactory.save(keiba_ai, version_name='basemodel_2022_2023')

# %% [markdown]
# # C.予測

# %% [markdown]
# ## 関数置き場

# %%
class ResultsProcessor(AbstractDataProcessor):
    def __init__(self, filepath):
        super().__init__(filepath)
    
    def _preprocess(self):
        """
        前処理
        """
        df = self.raw_data.copy()
        
        # 着順の前処理
        df = self._preprocess_rank(df)
        
        # 性齢を性と年齢に分ける
        # サイト上のテーブルに存在する列名は、ResultsColsクラスで定数化している。
        df["性"] = df[ResultsCols.SEX_AGE].map(lambda x: str(x)[0])
        df["年齢"] = df[ResultsCols.SEX_AGE].map(lambda x: str(x)[1:]).astype(int)

        # 馬体重を体重と体重変化に分ける
        df["体重"] = df[ResultsCols.WEIGHT_AND_DIFF].str.split("(", expand=True)[0]
        df["体重変化"] = df[ResultsCols.WEIGHT_AND_DIFF].str.split("(", expand=True)[1].str[:-1]
        
        # errors='coerce'で、"計不"など変換できない時に欠損値にする
        df['体重'] = pd.to_numeric(df['体重'], errors='coerce')
        df['体重変化'] = pd.to_numeric(df['体重変化'], errors='coerce')

        # 各列を数値型に変換
        df[ResultsCols.TANSHO_ODDS] = df[ResultsCols.TANSHO_ODDS].astype(float)
        df[ResultsCols.KINRYO] = df[ResultsCols.KINRYO].astype(float)
        df[ResultsCols.WAKUBAN] = df[ResultsCols.WAKUBAN].astype(int)
        df[ResultsCols.UMABAN] = df[ResultsCols.UMABAN].astype(int)
        
        # 6/6出走数追加
        df['n_horses'] = df.index.map(df.index.value_counts())
        
        # カラム抽出
        df = self._select_columns(df)
        
        return df
        
        
    def _preprocess_rank(self, raw):
        """
        着順の前処理
        """
        df = raw.copy()
        # 着順に数字以外の文字列が含まれているものを取り除く
        df[ResultsCols.RANK] = pd.to_numeric(df[ResultsCols.RANK], errors='coerce')
        df.dropna(subset=[ResultsCols.RANK], inplace=True)
        df[ResultsCols.RANK] = df[ResultsCols.RANK].astype(int)
        df['rank'] = df[ResultsCols.RANK].map(lambda x:1 if x<4 else 0)
        return df
    
    def _select_columns(self, raw):
        """
        カラム抽出
        """
        df = raw.copy()[[
            ResultsCols.WAKUBAN, # 枠番
            ResultsCols.UMABAN, # 馬番
            ResultsCols.KINRYO, # 斤量
            ResultsCols.TANSHO_ODDS, # 単勝
            'horse_id',
            'jockey_id',
            'trainer_id',
            'owner_id',
            '性',
            '年齢',
            '体重',
            '体重変化',
            'n_horses',
            'rank'
            ]]
        return df

class ShutubaTableProcessor(ResultsProcessor):
    def __init__(self, filepath: str):
        super().__init__(filepath)

    def _preprocess(self):
        df = super()._preprocess()
        
        # 距離は10の位を切り捨てる
        df["course_len"] = df["course_len"].astype(float) // 100
        
        # 開催場所
        df['開催'] = df.index.map(lambda x:str(x)[4:6])
        
        # 日付型に変更
        df["date"] = pd.to_datetime(df["date"])
        return df
    
    def _preprocess_rank(self, raw):
        return raw
    
    def _select_columns(self, raw):
        df = raw.copy()[[\
            ResultsCols.WAKUBAN, # 枠番
            ResultsCols.UMABAN, # 馬番
            ResultsCols.KINRYO, # 斤量
            ResultsCols.TANSHO_ODDS, # 単勝
            'horse_id',
            'jockey_id',
            'trainer_id',
            '性',
            '年齢',
            '体重',
            '体重変化',
            'n_horses',
            'course_len',
            'weather',
            'race_type',
            'ground_state',
            'date',
            'around',
            'race_class'
            ]]
        return df

# %%
def create_active_race_id_list(minus_time=-50):
    # 現在時刻を取得
    now_date = datetime.datetime.now().date().strftime('%Y%m%d')
    hhmm = datetime.datetime.now().strftime("%H:%M")
    print(now_date, hhmm)

    # レースidとレース時刻の一覧を取得
    race_id_list, race_time_list = scrape_race_id_race_time_list(now_date)

    # 現在時刻マイナス馬体重時刻を取得
    t_delta30 = datetime.timedelta(hours = 9, minutes = minus_time)
    JST30 = datetime.timezone(t_delta30, 'JST')
    now30 = datetime.datetime.now(JST30)
    hhmm_minus_time = now30.strftime("%H:%M")

    target_race_id_list = []
    target_race_time_list = []
    from_time = '09:15'

    for (race_id, race_time) in zip(race_id_list, race_time_list):

        # レース時刻より馬体重発表時刻を算出
        dt1 = datetime.datetime(int(now_date[:4]), int(now_date[4:6]),
            int(now_date[6:8]), int(race_time[0:2]), int(race_time[3:5]))
        dt2 = dt1 + datetime.timedelta(minutes = minus_time)
        announce_weight_time = dt2.strftime("%H:%M")

        # 1Rの場合は、前回のレース時刻を馬体重発表時刻に設定
        if '01' == race_id_list[10:12]:
            from_time = announce_weight_time

        # 前回のレース時刻 ＜ 現在時刻 ＜ レース時刻
        if (from_time < hhmm < race_time):
            target_race_id_list.append(race_id)
            target_race_time_list.append(race_time)
        # 現在時刻マイナス馬体重時刻 ＜ 馬体重発表時刻 ＜＝ 現在時刻
        elif (hhmm_minus_time < announce_weight_time <= hhmm):
            target_race_id_list.append(race_id)
            target_race_time_list.append(race_time)
        # 前回のレース時刻を退避
        from_time = race_time

    return target_race_id_list, target_race_time_list

# %%
class ShutubaDataMerger(DataMerger):
        
    def merge(self):
        self._merge_horse_results()
        self._merge_horse_info()
        self._merge_peds()

class ShutubaTableProcessor(ResultsProcessor):
    def __init__(self, filepath: str):
        super().__init__(filepath)

    def _preprocess(self):
        df = super()._preprocess()
        
        # 距離は10の位を切り捨てる
        df["course_len"] = df["course_len"].astype(float) // 100
        
        # 開催場所
        df['開催'] = df.index.map(lambda x:str(x)[4:6])
        
        # 日付型に変更
        df["date"] = pd.to_datetime(df["date"])
        return df
    
    def _preprocess_rank(self, raw):
        return raw
    
    def _select_columns(self, raw):
        df = raw.copy()[[\
            Cols.WAKUBAN, # 枠番
            Cols.UMABAN, # 馬番
            Cols.KINRYO, # 斤量
            Cols.TANSHO_ODDS, # 単勝
            'horse_id',
            'jockey_id',
            'trainer_id',
            '性',
            '年齢',
            '体重',
            '体重変化',
            'n_horses',
            'course_len',
            'weather',
            'race_type',
            'ground_state',
            'date',
            'around',
            'race_class'
            ]]
        return df

# %%
#モデルの準備
keiba_ai = KeibaAIFactory.load('models/20231102/basemodel_2022_2023.pickle')

# %%
# 前日全レース予想用のレースidとレース発走時刻を取得
target_race_id_list, target_race_time_list = scrape_race_id_race_time_list('20231104')
print(len(target_race_id_list))
print(len(target_race_time_list))
yesterday = True

# %%
# 馬体重の発表されたレースID、レース時刻を取得（レース当日用）
target_race_id_list, target_race_time_list = create_active_race_id_list()
print((target_race_id_list))
print((target_race_time_list))
yesterday = False

# %%
# 一時的に出馬表を保存するパスを指定
filepath = 'data/tmp/shutuba.pickle'
today = '2023/11/04'

for race_id, race_time in zip(target_race_id_list, target_race_time_list):
    # 出馬表の取得
    scrape_shutuba_table(race_id, today, filepath)

    # 前日予想の場合
    if yesterday:
        # 前日予想の場合、馬体重を0（0）に補正
        pd2 = pd.read_pickle(filepath)
        pd2[ResultsCols.WEIGHT_AND_DIFF] = '0(0)'
        # 前日予想の場合、天候と馬場状態が公開されていない場合はこちらを有効にする
        pd2['weather'] = '晴'
        pd2['ground_state'] = '良'
        pd2.to_pickle(filepath)

    # 出馬表の加工
    shutuba_table_processor = ShutubaTableProcessor(filepath)

    # テーブルのマージ
    shutuba_data_merger = ShutubaDataMerger(
        shutuba_table_processor,
        horse_results_processor,
        horse_info_processor,
        peds_processor,
        target_cols=TARGET_COLS,
        group_cols=GROUP_COLS
    )
    shutuba_data_merger.merge()

    # 特徴量エンジニアリング
    feature_enginnering_shutuba = FeatureEngineering(shutuba_data_merger) \
        .add_interval()\
        .add_agedays()\
        .dumminize_ground_state()\
        .dumminize_race_type()\
        .dumminize_sex()\
        .dumminize_weather()\
        .encode_horse_id()\
        .encode_jockey_id()\
        .encode_trainer_id()\
        .encode_owner_id()\
        .encode_breeder_id()\
        .dumminize_kaisai()\
        .dumminize_around()\
        .dumminize_race_class()

    # 予測
    X = feature_enginnering_shutuba.featured_data.drop(['date'], axis=1)

    # 当日の出走情報テーブル（前処理前）
    df_tmp = shutuba_table_processor.raw_data[:1]

    i = 0
    for num in list(PLACE_DICT.values()):
        if num == race_id[4:6]:
            print(list(PLACE_DICT)[i] + race_id[10:12] + 'R ' + race_time + '発走 ' + str(df_tmp.iat[0, 12])
                + str(df_tmp.iat[0, 10]) + 'm ' + str(df_tmp.iat[0, 13]) + ' ' + str(df_tmp.iat[0, 15]))
            break
        i += 1

    print(keiba_ai.calc_score(X, StdScorePolicy).sort_values('score', ascending=False))
